# %% [markdown]
# # Видобуток та збагачення структурованих даних

# %% [markdown]
# ### ТЕОРЕТИЧНА ЧАСТИНА ТА ПРИКЛАДИ

# %% [markdown]
# Для роботи з структурованими табличними даними, які розміщені в реляційній БД [SQLite](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&cad=rja&uact=8&ved=2ahUKEwiUyMOv1orvAhWDK3cKHac9DyMQFjAAegQIBxAD&url=https%3A%2F%2Fru.wikipedia.org%2Fwiki%2FSQLite&usg=AOvVaw1s-RMK2VC2tXyDZxZXDYDo) в Python передбачена стандартна бібліотека [sqlite3](https://docs.python.org/3/library/sqlite3.html)

# %%
# підключення бібліотеки
import sqlite3

# %% [markdown]
# #### ПРИКЛАД ВИЛУЧЕННЯ ДАНИХ З БД
# Створити БД SQLite з ім'ям `FIT-3m`, та імпорувати в неї таблицю, що містить журнал групи `jornal`

# %%
# створюємо з'єднання з БД
conn = sqlite3.connect("FIT-3m.db")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9c60a5ee1161> in <module>
#       1 # створюємо з'єднання з БД
# ----> 2 conn = sqlite3.connect("FIT-3m.db")
#
# NameError: name 'sqlite3' is not defined

# %% [markdown]
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %%
# створюємо об'єкт `cursor`, що відповідає за реалізацію операцій з таблицями БД
cur = conn.cursor()

# %%
print(type(cur), end='\n\n')
print(dir(cur))
# Out:
# <class 'sqlite3.Cursor'>
#
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'arraysize', 'close', 'connection', 'description', 'execute', 'executemany', 'executescript', 'fetchall', 'fetchmany', 'fetchone', 'lastrowid', 'row_factory', 'rowcount', 'setinputsizes', 'setoutputsize']

# %% [markdown]
# ##### виведемо ВСІ записи таблиці `jornal`

# %%
# створимо інстанс для операції `SELECT`
students_cur = cur.execute("SELECT * FROM jornal")

# будуємо список записів за допомогою метода `fetchall()`
students_list = students_cur.fetchall()

_ = [print(x) for x in students_list]
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-92-64a8289b2d8e> in <module>
#       1 # створимо інстанс для операції `SELECT`
# ----> 2 students_cur = cur.execute("SELECT * FROM jornal")
#       3
#       4 # будуємо список записів за допомогою метода `fetchall()`
#       5 students_list = students_cur.fetchall()
#
# OperationalError: no such table: jornal

# %% [markdown]
# #### ПРИКЛАД ЗБАГАЧЕННЯ ДАНИХ З ЗОВНІШНЬОГО ДЖЕРЕЛА
#
# Додати до списка студентів їх оцінки за вступне тестування, які розташовані в csv файлі `test_result.csv`

# %% [markdown]
# імпортуємо `test_result.csv` в робочу БД як таблицю `test`
#
# [імпорт csv файла в sqlite через CLI](https://www.sqlitetutorial.net/sqlite-import-csv/)

# %% [markdown]
# ##### Cтворимо нову таблицю, яка буде містити вміст таблиці `jornal` та поле оцінок з таблиці `test`

# %%
# створимо вираз на побудову пустої таблиці `jornal_test` з відповідними полями
sql_stmt = "CREATE TABLE IF NOT EXISTS jornal_test \
              (Surname TEXT,         \
               Name TEXT,            \
               Email TEXT,           \
               Test_result INT);"

# виконаемо запит на створення таблиці
cur.execute(sql_stmt)

# перевіримо стан виконання операції - виведемо список таблиць
tables_list = cur.execute("SELECT name FROM sqlite_master WHERE type = 'table';")
tables_list.fetchall()
# Out:
# [('jornal_test',)]

# %%
# створимо запит на об'єднання таблиць 'jornal' та 'test' по прізвищу студента
sql_stmt = "SELECT jornal.*, test.\"Оцінка/100\" FROM  \
            jornal LEFT JOIN test ON jornal.Surname = test.\"Ім\'я\" "

# для перевірки виконаємо і виведемо результати запиту
cur.execute(sql_stmt).fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-7-6ca9d9ffa997> in <module>
#       4
#       5 # для перевірки виконаємо і виведемо результати запиту
# ----> 6 cur.execute(sql_stmt).fetchall()
#
# OperationalError: no such table: jornal

# %%
# заповнимо пусту таблицю результатми  запиту на злиття
_ = cur.execute("INSERT INTO jornal_test " + sql_stmt)

# %%
# збережемо вміст нової таблиці в список
jornal_test_list = cur.execute("SELECT * FROM jornal_test").fetchall()

_ = [print(x) for x in jornal_test_list]

# %%
# завершимо всі транзакції
conn.commit()

# закріємо з'єднання
conn.close()

# %% [markdown]
# #### ПРИКЛАД  ДЕСКРИПТИВНОГО АНАЛІЗУ ДАНИХ
#
# Провести [попередній аналіз](https://ru.wikipedia.org/wiki/Описательная_статистика) отриманих даних з ціллю виявленя відхилень, помилок та інших непридатних даних.

# %% [markdown]
# Сведемо результати аналізу в таблицю, яка має наступний вигляд:
#
# №| Показчик | Значення
# :--:|:-------|-------:
# 1| кількість спостережень | xx
# 2| кількість пустих значень | xx
# 4| середній бал|  xx.x
# 5| максимальний бал | xx
# 6| мінімальний бал  | xx
# 7| стандартне відхилення | xx.x
# 8| розмах вариації  | xx

# %%
# підключимо бібліотеку 'numpy' і дамо їй аліас 'np'
import numpy as np

# %% [markdown]
# ознайомитись з призначенням, можливостями та основним функціями [бібліотеки numpy](https://numpy.org)

# %%
# перетворимо список студетів в numpay матрицю
jornal_test_arr = np.array(jornal_test_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0091c4bacf45> in <module>
#       1 # перетворимо список студетів в numpay матрицю
# ----> 2 jornal_test_arr = np.array(jornal_test_list)
#
# NameError: name 'jornal_test_list' is not defined

# %%
print(type (jornal_test_arr), jornal_test_arr.shape)

# %%
# створимо масив с результатами тестів 
test_result = np.delete(jornal_test_arr, [0,1,2], 1)

# %%
# Значення 'None' - не є числом, то заміним його на 0
test_result[test_result == None] = 0

# %%
# будуємо словник з вихідними розрахунками
result_dict = {
    "кількість спостережень"   : len(test_result),
    "кількість пустих значень" : len(test_result) - np.count_nonzero(test_result),
    "середній бал"             : round(np.mean(test_result),1),
    "максимальний бал"         : np.max(test_result),
    "мінімальний бал"          : np.min(test_result[np.nonzero(test_result)]),
    "стандартне відхилення"    : round(np.std(test_result),1),
    "розмах вариації"          : np.max(test_result) - np.min(test_result[np.nonzero(test_result)]) 
    }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-09670bdb9107> in <module>
#       1 # будуємо словник з вихідними розрахунками
#       2 result_dict = {
# ----> 3     "кількість спостережень"   : len(test_result),
#       4     "кількість пустих значень" : len(test_result) - np.count_nonzero(test_result),
#       5     "середній бал"             : round(np.mean(test_result),1),
#
# NameError: name 'test_result' is not defined

# %%
result_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-24701a844412> in <module>
# ----> 1 result_dict
#
# NameError: name 'result_dict' is not defined

# %%
# вивести шапку
print(
"""
=======================================
№  : ПОКАЗЧИК               : ЗНАЧЕННЯ     
=======================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1
# Out:
# =======================================
# №  : ПОКАЗЧИК               : ЗНАЧЕННЯ
# =======================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f908f0a5e35b> in <module>
#      10 # вивести результати аналізу датасета
#      11 i = 1
# ---> 12 for key, value in result_dict.items():
#      13     print (f'{i:<3} {key:<25}  {value}')
#      14     i += 1
#
# NameError: name 'result_dict' is not defined

# %% [markdown]
# ### ІНДИВІДУАЛЬНЕ ЗАВДАННЯ

# %%
Користуючись результатами, що отримані в [Лабораторній роботі № 3](https://shkliarskiy.moodlecloud.com/mod/page/view.php?id=1193) виконати процедури видобутку, збагачення та попереднього аналізу даних.

__Постановка__: В 3-й лабораторній роботі отримано показчик, що характеризує окрему властивість квартири (ціна, метраж та ін.). 
Необхідно:
1. Відобразити цей показчик на адресу квартири, яка знаходиться в файлі `street_name.csv`, тобто побудувати новий файл `street_flat_propery.csv` якій містить 2 колонки: _<назва вулиці> <ваш показчик>_
2. На основі цьго файлу зробити відповідну таблицю в _SQLite_ та збагатити цю дані в цій таблиці назвою району де розташована квартира (дані по районах додаються) 
3. Провести попередній аналіз отриманих даних - вивести первинні статистики показчика по районах (_середне_ , _мінімальне_ , _максимальне_ і т.д. - див. приклад вище)
# Out:
#   File "<ipython-input-7-15e13dee90ed>", line 1
#     Користуючись результатами, що отримані в [Лабораторній роботі № 3](https://shkliarskiy.moodlecloud.com/mod/page/view.php?id=1193) виконати процедури видобутку, збагачення та попереднього аналізу даних.
#                  ^
# SyntaxError: invalid syntax

# %%
# Злиття файлу з показчиком та файлу з назвами вулиць в новий файл

YOUR_FILE = 'aprt_total_level.txt'
with open(YOUR_FILE) as f1, \
     open('street_name.csv') as f2, \
     open('street_flat_property.csv', 'w') as f3:
    
    for x, y in zip(f1, f2):
        line = f'{x[:-1].strip()},{y[:-1].strip()}\n'
        print(line)
        f3.write(line)
# Out:
# level,street
#
# 21,Омеляновича-Павленка
#
# 11,
#
# 5,Ованеса Туманяна
#
# 5,Петропавлівська
#
# 2,Дніпровська
#
# 2,Саксаганського
#
# 21,Івана Мазепи
#
# 4,Дніпровська
#
# 6,Ділова
#
# 2,Новодарницька
#
# 8,Ревуцького
#
# 2,Липківського
#
# 13,Бендукідзе
#
# 12,Введенська
#
# 12,Виноградний
#
# 5,Кайсарова
#
# 16,Ахматової
#
# 4,Радченка
#
# 3,Дніпровська
#
# 21,Ділова
#
# 3,Бориспільська
#
# 8,Болсуновська
#
# 5,Українки
#
# 5,Антонова
#
# 3,Омеляновича-Павленка
#
# 7,
#
# 14,Ованеса Туманяна
#
# 6,Петропавлівська
#
# 19,Дніпровська
#
# 1,Саксаганського
#
# 7,Івана Мазепи
#
# 12,Дніпровська
#
# 6,Ділова
#
# 1,Новодарницька
#
# 24,Ревуцького
#
# 11,Липківського
#
# 5,Бендукідзе
#
# 9,Введенська
#
# 3,Виноградний
#
# 15,Кайсарова
#
# 3,Ахматової
#
# 15,Радченка
#
# 9,Дніпровська
#
# 17,Ділова
#
# 22,Бориспільська
#
# 1,Болсуновська
#
# 14,Українки
#
# 5,Антонова
#
# 12,Науки
#
# 4,Метрологічна
#
# 5,Дружби Народів
#
# 16,*** not found
#
# 14,Драгомирова
#
# 13,Данченка
#
# 3,Кримська
#
# 10,Новопольова
#
# 7,Туполєва
#
# 6,*** not found
#
# 9,Дніпровська
#
# 10,Перемоги
#
# 9,Івана Федорова
#
# 2,Братиславська
#
# 3,*** not found
#
# 3,Червоноткацька
#
# 5,Златоустівська
#
# 0,Бойченка
#
# 29,Трускавецька
#
# 2,Каховська
#
# 16,Лобановського
#
# 4,*** not found
#
# 3,Курчатова
#
# 21,Голосіївська
#
# 12,Тираспольська
#
# 4,Лаврська
#
# 5,Правди
#
# 16,Миколайчука
#
# 14,Порика
#
# 13,Червоноткацька
#
# 3,Маккейна
#
# 10,Йорданська
#
# 7,Тютюнника
#
# 6,Регенераторна
#
# 9,Зарічна
#
# 10,Заболотного
#
# 9,Курнатовського
#
# 2,Інститутська
#
# 3,Маланюка
#
# 3,Гречка
#
# 5,Липківського
#
# 0,Маккейна
#
# 29,Григоренка
#
# 2,Коновальця
#
# 16,Закревського
#
# 4,*** not found
#
# 3,Старонаводницька
#
# 21,Маланюка
#
# 6,Заньковецької
#
# 7,Кудрявська
#
# 10,
#
# 2,Українки
#
# 5,
#
# 2,Милославська
#
# 2,Донця
#
# 23,Верховинця
#
# 2,Героїв Дніпра
#
# 7,Каховська
#
# 11,Каховська
#
# 4,Вишняківська
#
# 6,Липська
#
# 9,Сверстюка
#
# 4,Драгомирова
#
# 18,Причальна
#
# 5,Болсуновська
#
# 3,Повітрофлотський
#
# 3,Драгоманова
#
# 5,Григоренка
#
# 23,Дніпровська
#
# 3,Жабаєва
#
# 8,Філатова
#
# 9,Правди
#
# 3,Малопідвальна
#
# 3,Бойчука
#
# 7,Зарічна
#
# 5,Предславинська
#
# 3,Івана Мазепи
#
# 11,Радченка
#
# 17,Лабораторний
#
# 19,Конєва
#
# 4,Шаповала
#
# 19,Дніпровська
#
# 6,Клеманська
#
# 4,Григоренка
#
# 23,Туполєва
#
# 9,Хмельницького
#
# 3,Саперне Поле
#
# 3,Героїв Сталінграда
#
# 12,Дніпровська
#
# 2,Тарасівська
#
# 6,Краківська
#
# 4,Юнацька
#
# 10,Клеманська
#
# 8,Героїв Сталінграда
#
# 2,Драгомирова
#
# 3,*** not found
#
# 23,Драгоманова
#
# 2,Українки
#
# 7,Тимошенка
#
# 3,Маяковського
#
# 3,Дмитрівська
#
# 2,Курбаса
#
# 11,Комарова
#
# 21,Драгоманова
#
# 2,Драгомирова
#
# 7,Моторний
#
# 10,Милославська
#
# 13,Бойчука
#
# 22,Закревського
#
# 5,Івана Федорова
#
# 17,Філатова
#
# 13,Перемоги
#
# 6,Миропільська
#
# 11,Григоренка
#
# 9,Юнацька
#
# 1,Вишгородська
#
# 1,Жолудєва
#
# 17,Павлівська
#
# 11,Голосіївський
#
# 4,Осокорська
#
# 10,Вишгородська
#
# 12,Драгомирова
#
# 5,Тютюнника
#
# 5,Маккейна
#
# 7,Івана Мазепи
#
# 9,Героїв Сталінграда
#
# 23,Липківського
#
# 15,*** not found
#
# 12,Коновальця
#
# 22,Максимовича
#
# 6,Зарічна
#
# 6,Голосіївська
#
# 5,Ясинуватський
#
# 8,*** not found
#
# 0,Колоса
#
# 2,Правди
#
# 2,Велика Васильківська
#
# 1,Голосіївський
#
# 7,*** not found
#
# 2,Бойчука
#
# 3,Центральна
#
# 2,Ясинуватський
#
# 3,Райдужна
#
# 23,Ломоносова
#
# 3,
#
# 15,*** not found
#
# 7,Гусовського
#
# 19,Окіпної
#
# 3,Багговутівська
#
# 9,Дружби Народів
#
# 5,Маккейна
#
# 15,Маланюка
#
# 4,Михайла Котельникова
#
# 15,Героїв Севастополя
#
# 7,Маланюка
#
# 14,Саперне Поле
#
# 1,Балтійський
#
# 8,Кудрявська
#
# 6,Перемоги
#
# 16,Німанська
#
# 2,Каховська
#
# 1,Малопідвальна
#
# 4,Невська
#
# 20,Златоустівська
#
# 4,
#
# 12,Берковецька
#
# 16,Бажана
#
# 0,Антоновича
#
# 2,*** not found
#
# 8,Гречка
#
# 2,Микільсько-Слобідська
#
# 15,Правди
#
# 22,Тимошенка
#
# 6,Павла Тичини
#
# 4,Олевська
#
# 13,Освіти
#
# 3,Іллєнка
#
# 25,Дніпровська
#
# 9,Івана Мазепи
#
# 6,Українки
#
# 27,Данченка
#
# 12,Драгомирова
#
# 9,Тбіліський
#
# 9,Каховська
#
# 0,Ушинського
#
# 11,Урлівська
#
# 26,Світлицького
#
# 21,Дніпровська
#
# 14,Липківського
#
# 1,Микільсько-Слобідська
#
# 3,Лобановського
#
# 4,Героїв Сталінграда
#
# 16,Дніпровська
#
# 20,Драгоманова
#
# 11,Ахматової
#
# 4,Саперне Поле
#
# 16,Данченка
#
# 24,Голосіївський
#
# 2,*** not found
#
# 22,Глибочицька
#
# 10,Багговутівська
#
# 16,Саксаганського
#
# 4,Моторний
#
# 9,Йорданська
#
# 12,Саперне Поле
#
# 18,Вернадського
#
# 12,Курбаса
#
# 5,Багговутівська
#
# 6,Набережно-Рибальська
#
# 1,Саксаганського
#
# 4,Малиновського
#
# 3,Протасів Яр
#
# 8,Німанська
#
# 6,Підвисоцького
#
# 6,Зодчих
#
# 25,Рокосовського
#
# 11,Шовковична
#
# 6,Крушельницької
#
# 5,Новопольова
#
# 15,Визволителів
#
# 0,Сонячна
#
# 4,Сікорського
#
# 5,Радченка
#
# 5,Бульварно-Кудрявська
#
# 20,Кайсарова
#
# 13,Дніпровська
#
# 7,Перова
#
# 5,Глушкова
#
# 21,Рокосовського
#
# 21,Саперно-Слобідська
#
# 1,Миколи Кибальчича
#
# 11,Миколи Ушакова
#
# 2,Антоновича
#
# 2,Богданівська
#
# 9,
#
# 15,Сверстюка
#
# 14,Ревуцького
#
# 0,Ованеса Туманяна
#
# 4,Саперне Поле
#
# 8,Григоренка
#
# 16,Гречка
#
# 3,Богатирська
#
# 16,Білоруська
#
# 0,Регенераторна
#
# 9,Вишняківська
#
# 9,Гонгадзе
#
# 5,Правди
#
# 3,Кольцова
#
# 17,Воскресенська
#
# 0,Руставелі
#
# 10,Голосіївський
#
# 6,Комбінатна
#
# 9,Салютна
#
# 14,Маланюка
#
# 0,Ромоданова
#
# 21,Саперне Поле
#
# 10,Сім’ї Кульженків
#
# 21,Лабораторна
#
# 4,Драгоманова
#
# 5,
#
# 12,Кудрявська
#
# 0,Краківська
#
# 6,Кольцова
#
# 7,Антоновича
#
# 12,Лариси Руденко
#
# 12,Івана Пулюя
#
# 19,Українки
#
# 9,Тютюнника
#
# 14,Юрія Смолича
#
# 18,Оболонський
#
# 23,Курбаса
#
# 8,Верховинця
#
# 21,Зарічна
#
# 3,Дніпровська
#
# 24,Коломийський
#
# 19,Правди
#
# 4,Каховська
#
# 9,Бойчука
#
# 3,Правди
#
# 5,Маккейна
#
# 16,Перемоги
#
# 4,Грушевського
#
# 3,Срібнокільська
#
# 1,Перемоги
#
# 9,Урлівська
#
# 2,Заболотного
#
# 22,Максимовича
#
# 11,Бажана
#
# 9,Сікорського
#
# 14,Курбаса
#
# 4,Дніпровська
#
# 10,Драгомирова
#
# 2,
#
# 3,Антонова
#
# 9,Бучми
#
# 0,Кубанської України
#
# 0,Дніпровська
#
# 2,Панельна
#
# 16,Коновальця
#
# 8,Богатирська
#
# 2,Оболонський
#
# 0,Українки
#
# 6,Бориса Гмирі
#
# 10,Правди
#
# 1,Центральна
#
# 26,Преображенська
#
# 0,Коновальця
#
# 6,Українки
#
# 20,*** not found
#
# 12,Велика Васильківська
#
# 15,Липківського
#
# 16,Бойчука
#
# 7,Васильківська
#
# 0,Данькевича
#
# 28,Богатирська
#
# 16,Українки
#
# 7,Гречка
#
# 7,Редутна
#
# 11,Бориса Гмирі
#
# 6,Драгомирова
#
# 11,Туполєва
#
# 12,Кондратюка
#
# 15,Мінський
#
# 4,Княжий Затон
#
# 6,Герцена
#
# 4,Балтійський
#
# 8,Ернста
#
# 6,Шаповала
#
# 5,Городецького
#
# 18,Сім'ї Сосніних
#
# 16,Івана Мазепи
#
# 5,Червоноткацька
#
# 6,*** not found
#
# 7,Голосіївська
#
# 25,*** not found
#
# 13,Миколи Гулака
#
# 13,Івана Федорова
#
# 2,Саперне Поле
#
# 16,Миколи Хвильового
#
# 19,Паторжинського
#
# 9,Наумовича
#
# 3,Калнишевського
#
# 1,Дніпровська
#
# 9,Електриків
#
# 1,Солом'янська
#
# 21,Шевченка
#
# 20,Озерна
#
# 15,Григоренка
#
# 8,Антонова
#
# 9,Голосіївський
#
# 8,Комарова
#
# 10,Борщагівська
#
# 7,Шевченка
#
# 5,Максимовича
#
# 10,Ковальський
#
# 2,Малевича
#
# 10,Мічуріна
#
# 3,*** not found
#
# 4,Балтійський
#
# 7,Азербайджанська
#
# 12,Зарічна
#
# 16,Чавдар
#
# 4,Правди
#
# 5,Урлівська
#
# 8,Бориспільська
#
# 4,Поправки
#
# 3,Бориспільська
#
# 3,Ентузіастів
#
# 11,Малоземельна
#
# 18,Саксаганського
#
# 12,Героїв Сталінграда
#
# 25,Зодчих
#
# 4,Калнишевського
#
# 11,Філатова
#
# 1,Старонаводницька
#
# 8,Заболотного
#
# 2,Правди
#
# 10,*** not found
#
# 18,Антоновича
#
# 7,Шаповала
#
# 4,Івана Федорова
#
# 13,Деревлянська
#
# 23,Вільямса
#
# 26,Васильченка
#
# 9,Предславинська
#
# 13,Крайня
#
# 8,Милославська
#
# 9,Воскресенська
#
# 1,Маланюка
#
# 1,Дніпровська
#
# 21,Пушкінська
#
# 13,Набережно-Корчуватська
#
# 8,Зарічна
#
# 5,Тургенєвська
#
# 9,Радченка
#
# 1,Зарічна
#
# 4,Метрологічна
#
# 12,Йорданська
#
# 2,Кольцова
#
# 22,Максимовича
#
# 3,Науки
#
# 15,Саперно-Слобідська
#
# 16,Шовковична
#
# 4,Трускавецька
#
# 4,Гавела
#
# 2,Повітрофлотський
#
# 2,Запорожця
#
# 10,Маккейна
#
# 13,Перемоги
#
# 26,Щербаківського
#
# 6,Зарічна
#
# 3,Будищанська
#
# 5,Жилянська
#
# 5,Комбінатна
#
# 23,Ревуцького
#
# 18,Бородіна
#
# 6,Руставелі
#
# 10,Драгоманова
#
# 3,Преображенська
#
# 0,Депутатська
#
# 8,Багговутівська
#
# 10,*** not found
#
# 6,Сікорського
#
# 2,Драгомирова
#
# 2,Коперніка
#
# 0,Васильківська
#
# 9,Глибочицька
#
# 23,Чавдар
#
# 25,Шовковична
#
# 24,Дніпровська
#
# 0,Антоновича
#
# 7,
#
# 4,Славгородська
#
# 3,Драгомирова
#
# 15,Срібнокільська
#
# 10,Харченка
#
# 4,Окіпної
#
# 0,Саперне Поле
#
# 11,Олени Теліги
#
# 10,Кондратюка
#
# 1,Мечнікова
#
# 7,Героїв Сталінграда
#
# 25,Рибальська
#
# 8,Березова
#
# 7,Саперне Поле
#
# 23,Антоновича
#
# 3,Маккейна
#
# 17,Лейпцизька
#
# 14,Драгоманова
#
# 23,Коновальця
#
# 3,Василя Стуса
#
# 24,Тютюнника
#
# 15,Січових Стрільців
#
# 6,Райдужна
#
# 15,Закревського
#
# 9,Тургенєвська
#
# 20,Васильківська
#
# 20,Зої Космодем'янської
#
# 18,Радченка
#
# 8,Сверстюка
#
# 24,Милославська
#
# 23,Метрологічна
#
# 4,Деміївська
#
# 1,Перемоги
#
# 13,Вишгородська
#
# 23,Маккейна
#
# 14,
#
# 4,Перемоги
#
# 4,Балтійський
#
# 1,Звіринецька
#
# 13,Ревуцького
#
# 9,Правди
#
# 15,Милославська
#
# 18,Вербицького
#
# 22,Новгородська
#
# 17,Бажана
#
# 11,Канівська
#
# 3,Максимовича
#
# 11,Донця
#
# 4,Драгомирова
#
# 4,Тираспольська
#
# 3,Саксаганського
#
# 7,Тираспольська
#
# 1,Зарічна
#
# 23,Гонгадзе
#
# 9,Українки
#
# 15,Світлицького
#
# 18,Воробйова
#
# 16,Каховська
#
# 7,Глибочицька
#
# 25,Білокур
#
# 25,Балтійський
#
# 7,Антоновича
#
# 9,Кондратюка
#
# 1,Гончара
#
# 2,Ревуцького
#
# 8,*** not found
#
# 4,Драгоманова
#
# 24,Сім’ї Кульженків
#
# 13,Панельна
#
# 4,Вільямса
#
# 2,Голосіївська
#
# 18,Оболонський
#
# 6,Миколи Голего
#
# 17,Дніпровська
#
# 11,Малиновського
#
# 9,Назарівська
#
# 23,Гоголівська
#
# 4,Дорогожицька
#
# 15,Петропавлівська
#
# 6,Грушевського
#
# 21,Іллєнка
#
# 10,Липківського
#
# 8,Ушинського
#
# 10,Польова
#
# 5,Саперне Поле
#
# 6,Панельна
#
# 4,Коновальця
#
# 3,Хмельницького
#
# 9,Маккейна
#
# 24,Антоновича
#
# 5,Толстого
#
# 9,Дружби Народів
#
# 17,Оболонський
#
# 17,Багговутівська
#
# 20,Антонова
#
# 4,Володимирська
#
# 22,Українки
#
# 3,Сім’ї Кульженків
#
# 1,Коновальця
#
# 28,Мирного
#
# 0,Московська
#
# 5,Жмеринська
#
# 12,Бойчука
#
# 5,Липківського
#
# 8,Лабораторний
#
# 0,Інститутська
#
# 7,Українки
#
# 3,Хрещатик
#
# 20,Дніпровська
#
# 14,Осокорська
#
# 2,Саперне Поле
#
# 13,Комарова
#
# 0,Драгомирова
#
# 3,Срібнокільська
#
# 22,Чоколівський
#
# 4,Звіринецька
#
# 7,Вишгородська
#
# 11,Драгомирова
#
# 0,Героїв Сталінграда
#
# 0,Будівельників
#
# 2,Іллєнка
#
# 3,Урлівська
#
# 9,Сормовська
#
# 0,Правди
#
# 7,Верховинна
#
# 17,Вербицького
#
# 1,*** not found
#
# 15,Велика Васильківська
#
# 11,Бойчука
#
# 9,Лобановського
#
# 0,Миколи Шепелєва
#
# 21,Кропивницького
#
# 7,Трускавецька
#
# 28,Голосіївська
#
# 4,Маланюка
#
# 4,Драгомирова
#
# 24,Юнацька
#
# 5,Максимовича
#
# 3,Комарова
#
# 1,Багговутівська
#
# 7,
#
# 10,Костанайська
#
# 10,Срібнокільська
#
# 1,Курчатова
#
# 4,Гусовського
#
# 5,Українки
#
# 23,Драгоманова
#
# 18,Дніпровська
#
# 9,Заболотного
#
# 4,Заболотного
#
# 7,Перемоги
#
# 3,Сверстюка
#
# 2,Липківського
#
# 16,Маккейна
#
# 12,Дніпровська
#
# 4,Волгоградська
#
# 5,Новопольова
#
# 3,Драгоманова
#
# 16,Лебедєва
#
# 3,*** not found
#
# 10,Драгомирова
#
# 22,Лейпцизька
#
# 10,Глибочицька
#
# 4,Салютна
#
# 0,Метрологічна
#
# 18,Північно-Сирецька
#
# 1,Правди
#
# 1,Вернадського
#
# 6,Пчілки
#
# 12,Лейпцизька
#
# 0,Басейна
#
# 8,Шаповала
#
# 2,Бережанська
#
# 17,Бойчука
#
# 6,Перемоги
#
# 0,Івана Федорова
#
# 18,Антоновича
#
# 4,Вільямса
#
# 14,Бойчука
#
# 2,Перемоги
#
# 9,Ковпака
#
# 3,Русанівський
#
# 0,Українки
#
# 5,Празька
#
# 15,Гончара
#
# 24,Маккейна
#
# 4,Балтійський
#
# 2,Білоруська
#
# 9,Драгоманова
#
# 14,Липківського
#
# 12,Новогоспітальна
#
# 3,Радченка
#
# 9,Богомольця
#
# 9,Донця
#
# 3,Оболонський
#
# 9,Щекавицька
#
# 22,Пожарського
#
# 25,Полкова
#
# 9,Донця
#
# 3,Палладіна
#
# 17,Бойчука
#
# 0,Липківського
#
# 21,Павлівська
#
# 2,Івашкевича
#
# 15,Іскрівська
#
# 1,Максимовича
#
# 6,*** not found
#
# 18,Драгомирова
#
# 22,Теремківська
#
# 19,Осокорська
#
# 24,Дмитрівська
#
# 5,Кондратюка
#
# 22,Регенераторна
#
# 3,
#
# 25,Глибочицька
#
# 12,Героїв Сталінграда
#
# 0,Борщагівська
#
# 21,Ревуцького
#
# 19,Юнацька
#
# 21,Заболотного
#
# 8,Автозаводська
#
# 17,Заболотного
#
# 0,Саксаганського
#
# 6,Зарічна
#
# 20,*** not found
#
# 8,Невська
#
# 12,Героїв Сталінграда
#
# 0,Вишняківська
#
# 8,Драгомирова
#
# 15,Драгомирова
#
# 1,Гавела
#
# 18,Здолбунівська
#
# 15,Драгомирова
#
# 2,Мечнікова
#
# 0,*** not found
#
# 2,Максимовича
#
# 3,Багговутівська
#
# 24,Шолуденка
#
# 5,Щекавицька
#
# 4,Коласа
#
# 15,*** not found
#
# 6,*** not found
#
# 9,Перемоги
#
# 23,*** not found
#
# 29,Наумова
#
# 5,Перемоги
#
# 19,Велика Васильківська
#
# 11,Червоноткацька
#
# 7,Вишгородська

# %% [markdown]
# #### імпортувати в БД отриманий файл 'street_flat_propery.csv' через CLI
# - __sqlite3 districts.db__ - запустити SQLite та відкрити БД
# - __.mode csv__ - перевести БД для роботи з csv-файлами
# - __.import street_flat_propery.csv street_flat_propery__ - створює таблицю _street_flat_propery_ та завантажує в неї вміст файлу _street_flat_propery.csv_
# - __SELECT * FROM street_flat_propery LIMIT 10;__ - вивести 10 записів для перевірки
# - __.quit__ - завершити роботу з CLI SQLite

# %%
# Підключитись до БД 'districts.db' в якій є прив'язка вулиць до районів 
conn = sqlite3.connect("districts.db")

# створити відповідний курсор
cur  = conn.cursor()

# %%
# для перевірки виведіть 10 записів з таблиці 'street_district'
rows = cur.execute("SELECT * FROM street_district LIMIT 10")

rows_list = rows.fetchall()

_ = [print(x) for x in rows_list]
# Out:
# ('9-го Травня', 'вулиця', 'Святошинський')
# ('Абрикосова', 'вулиця', 'Оболонський')
# ('Абрикосова', 'вулиця', 'Дарницький')
# ('Абрикосова', 'вулиця', 'Подільський')
# ('Августина Волошина', 'вулиця', 'Солом’янський')
# ('Авдєєнка Генерала', 'вулиця', 'Святошинський')
# ('Автозаводська', 'вулиця', 'Оболонський')
# ('Автозаводський ', 'провулок', 'Оболонський')
# ('Автопаркова', 'вулиця', 'Дарницький')
# ('Авторемонтна', 'вулиця', "Солом'янський")

# %%
# побудувати запит на створення таблиці 'result' з 3-ма полями:
#     district - текстове
#     street - текстове
#     property - числове
stmt = "CREATE TABLE IF NOT EXISTS result \
              (district TEXT,         \
               street TEXT,            \
               property INT);"

# %%
# виконати запит
cur.execute(stmt)

# %%
# перевірити схему таблиці
cur.execute ("SELECT name FROM PRAGMA_TABLE_INFO('result');").fetchall()
# Out:
# [('district',), ('street',), ('property',)]

# %%
# створити запит на злиття таблиці 'street_flat_propery' та 'street_district' 
# по полю 'street'
stmt_join = "SELECT street_district.district, street_flat_property.* FROM \
             street_flat_property LEFT JOIN street_district ON street_flat_property.street = street_district.street"

# %%
# перевірити запит
cur.execute(stmt_join).fetchall()
# Out:
# [(None, 21, 'Омеляновича-Павленка'),
#  (None, 11, None),
#  (None, 5, 'Ованеса Туманяна'),
#  ('Оболонський', 5, 'Петропавлівська'),
#  ('Подільський', 5, 'Петропавлівська'),
#  ('Оболонський', 2, 'Дніпровська'),
#  ('Голосіївський, Печерський, Шевченківський', 2, 'Саксаганського'),
#  (None, 21, 'Івана Мазепи'),
#  ('Оболонський', 4, 'Дніпровська'),
#  ('Голосіївський, Печерський', 6, 'Ділова'),
#  (None, 2, 'Новодарницька'),
#  ('Дарницький', 8, 'Ревуцького'),
#  (None, 2, 'Липківського'),
#  (None, 13, 'Бендукідзе'),
#  ('Подільський', 12, 'Введенська'),
#  ('Печерський', 12, 'Виноградний'),
#  ("Голосіївський,Солом'янський", 5, 'Кайсарова'),
#  (None, 16, 'Ахматової'),
#  (None, 4, 'Радченка'),
#  ('Оболонський', 3, 'Дніпровська'),
#  ('Голосіївський, Печерський', 21, 'Ділова'),
#  ('Дарницький', 3, 'Бориспільська'),
#  ('Печерський', 8, 'Болсуновська'),
#  (None, 5, 'Українки'),
#  (None, 5, 'Антонова'),
#  (None, 3, 'Омеляновича-Павленка'),
#  (None, 7, None),
#  (None, 14, 'Ованеса Туманяна'),
#  ('Оболонський', 6, 'Петропавлівська'),
#  ('Подільський', 6, 'Петропавлівська'),
#  ('Оболонський', 19, 'Дніпровська'),
#  ('Голосіївський, Печерський, Шевченківський', 1, 'Саксаганського'),
#  (None, 7, 'Івана Мазепи'),
#  ('Оболонський', 12, 'Дніпровська'),
#  ('Голосіївський, Печерський', 6, 'Ділова'),
#  (None, 1, 'Новодарницька'),
#  ('Дарницький', 24, 'Ревуцького'),
#  (None, 11, 'Липківського'),
#  (None, 5, 'Бендукідзе'),
#  ('Подільський', 9, 'Введенська'),
#  ('Печерський', 3, 'Виноградний'),
#  ("Голосіївський,Солом'янський", 15, 'Кайсарова'),
#  (None, 3, 'Ахматової'),
#  (None, 15, 'Радченка'),
#  ('Оболонський', 9, 'Дніпровська'),
#  ('Голосіївський, Печерський', 17, 'Ділова'),
#  ('Дарницький', 22, 'Бориспільська'),
#  ('Печерський', 1, 'Болсуновська'),
#  (None, 14, 'Українки'),
#  (None, 5, 'Антонова'),
#  ('Голосіївський', 12, 'Науки'),
#  ('Голосіївський', 4, 'Метрологічна'),
#  ('Печерський', 5, 'Дружби Народів'),
#  (None, 16, '*** not found'),
#  (None, 14, 'Драгомирова'),
#  (None, 13, 'Данченка'),
#  ('Голосіївський', 3, 'Кримська'),
#  ("Солом'янський", 10, 'Новопольова'),
#  (None, 7, 'Туполєва'),
#  (None, 6, '*** not found'),
#  ('Оболонський', 9, 'Дніпровська'),
#  ('Святошинський', 10, 'Перемоги'),
#  ('Шевченківський', 10, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 10, 'Перемоги'),
#  (None, 9, 'Івана Федорова'),
#  ('Деснянський, Дніпровський', 2, 'Братиславська'),
#  (None, 3, '*** not found'),
#  (None, 3, 'Червоноткацька'),
#  (None, 5, 'Златоустівська'),
#  (None, 0, 'Бойченка'),
#  ('Дарницький', 29, 'Трускавецька'),
#  ('Дніпровський', 2, 'Каховська'),
#  (None, 16, 'Лобановського'),
#  (None, 4, '*** not found'),
#  (None, 3, 'Курчатова'),
#  ('Голосіївський', 21, 'Голосіївська'),
#  ('Голосіївський', 21, 'Голосіївська'),
#  ('Подільський', 12, 'Тираспольська'),
#  ('Печерський', 4, 'Лаврська'),
#  ('Подільський', 5, 'Правди'),
#  (None, 16, 'Миколайчука'),
#  (None, 14, 'Порика'),
#  (None, 13, 'Червоноткацька'),
#  (None, 3, 'Маккейна'),
#  ('Оболонський', 10, 'Йорданська'),
#  (None, 7, 'Тютюнника'),
#  ('Дніпровський', 6, 'Регенераторна'),
#  ('Дарницький', 9, 'Зарічна'),
#  (None, 10, 'Заболотного'),
#  ('Дніпровський, Деснянський', 9, 'Курнатовського'),
#  ('Печерський', 2, 'Інститутська'),
#  (None, 3, 'Маланюка'),
#  (None, 3, 'Гречка'),
#  (None, 5, 'Липківського'),
#  (None, 0, 'Маккейна'),
#  (None, 29, 'Григоренка'),
#  (None, 2, 'Коновальця'),
#  (None, 16, 'Закревського'),
#  (None, 4, '*** not found'),
#  ('Печерський', 3, 'Старонаводницька'),
#  (None, 21, 'Маланюка'),
#  ('Печерський', 6, 'Заньковецької'),
#  ('Шевченківський', 7, 'Кудрявська'),
#  (None, 10, None),
#  (None, 2, 'Українки'),
#  (None, 5, None),
#  ('Деснянський', 2, 'Милославська'),
#  (None, 2, 'Донця'),
#  (None, 23, 'Верховинця'),
#  ('Оболонський', 2, 'Героїв Дніпра'),
#  ('Дніпровський', 7, 'Каховська'),
#  ('Дніпровський', 11, 'Каховська'),
#  ('Дарницький', 4, 'Вишняківська'),
#  (None, 6, 'Липська'),
#  (None, 9, 'Сверстюка'),
#  (None, 4, 'Драгомирова'),
#  ('Дарницький', 18, 'Причальна'),
#  ('Печерський', 5, 'Болсуновська'),
#  ("Шевченківський, Солом'янський", 3, 'Повітрофлотський'),
#  ('Дарницький', 3, 'Драгоманова'),
#  (None, 5, 'Григоренка'),
#  ('Оболонський', 23, 'Дніпровська'),
#  (None, 3, 'Жабаєва'),
#  (None, 8, 'Філатова'),
#  ('Подільський', 9, 'Правди'),
#  ('Шевченківський', 3, 'Малопідвальна'),
#  (None, 3, 'Бойчука'),
#  ('Дарницький', 7, 'Зарічна'),
#  ('Печерський', 5, 'Предславинська'),
#  (None, 3, 'Івана Мазепи'),
#  (None, 11, 'Радченка'),
#  ('Печерський', 17, 'Лабораторний'),
#  (None, 19, 'Конєва'),
#  (None, 4, 'Шаповала'),
#  ('Оболонський', 19, 'Дніпровська'),
#  ('Дарницький', 6, 'Клеманська'),
#  (None, 4, 'Григоренка'),
#  (None, 23, 'Туполєва'),
#  (None, 9, 'Хмельницького'),
#  ('Печерський', 3, 'Саперне Поле'),
#  ('Оболонський', 3, 'Героїв Сталінграда'),
#  ('Оболонський', 12, 'Дніпровська'),
#  ('Голосіївський', 2, 'Тарасівська'),
#  ('Дніпровський', 6, 'Краківська'),
#  ('Святошинський', 4, 'Юнацька'),
#  ("Солом'янський", 4, 'Юнацька'),
#  ('Дарницький', 10, 'Клеманська'),
#  ('Оболонський', 8, 'Героїв Сталінграда'),
#  (None, 2, 'Драгомирова'),
#  (None, 3, '*** not found'),
#  ('Дарницький', 23, 'Драгоманова'),
#  (None, 2, 'Українки'),
#  (None, 7, 'Тимошенка'),
#  ('Деснянський', 3, 'Маяковського'),
#  ('Подільський', 3, 'Дмитрівська'),
#  ('Шевченківський', 3, 'Дмитрівська'),
#  (None, 2, 'Курбаса'),
#  (None, 11, 'Комарова'),
#  ('Дарницький', 21, 'Драгоманова'),
#  (None, 2, 'Драгомирова'),
#  (None, 7, 'Моторний'),
#  ('Деснянський', 10, 'Милославська'),
#  (None, 13, 'Бойчука'),
#  (None, 22, 'Закревського'),
#  (None, 5, 'Івана Федорова'),
#  (None, 17, 'Філатова'),
#  ('Святошинський', 13, 'Перемоги'),
#  ('Шевченківський', 13, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 13, 'Перемоги'),
#  ('Деснянський, Дніпровський', 6, 'Миропільська'),
#  (None, 11, 'Григоренка'),
#  ('Святошинський', 9, 'Юнацька'),
#  ("Солом'янський", 9, 'Юнацька'),
#  ('Подільський, Оболонський', 1, 'Вишгородська'),
#  ('Святошинський', 1, 'Жолудєва'),
#  ('Шевченківський', 17, 'Павлівська'),
#  ('Голосіївський', 11, 'Голосіївський'),
#  ('Голосіївський', 11, 'Голосіївський'),
#  ('Дарницький', 4, 'Осокорська'),
#  ('Подільський, Оболонський', 10, 'Вишгородська'),
#  (None, 12, 'Драгомирова'),
#  (None, 5, 'Тютюнника'),
#  (None, 5, 'Маккейна'),
#  (None, 7, 'Івана Мазепи'),
#  ('Оболонський', 9, 'Героїв Сталінграда'),
#  (None, 23, 'Липківського'),
#  (None, 15, '*** not found'),
#  (None, 12, 'Коновальця'),
#  ('Святошинський', 22, 'Максимовича'),
#  ('Дарницький', 6, 'Зарічна'),
#  ('Голосіївський', 6, 'Голосіївська'),
#  ('Голосіївський', 6, 'Голосіївська'),
#  ('Голосіївський', 5, 'Ясинуватський'),
#  (None, 8, '*** not found'),
#  (None, 0, 'Колоса'),
#  ('Подільський', 2, 'Правди'),
#  ('Голосіївський, Шевченківський, Печерський', 2, 'Велика Васильківська'),
#  ('Голосіївський', 1, 'Голосіївський'),
#  ('Голосіївський', 1, 'Голосіївський'),
#  (None, 7, '*** not found'),
#  (None, 2, 'Бойчука'),
#  ('Дніпровський', 3, 'Центральна'),
#  ('Оболонський', 3, 'Центральна'),
#  ('Шевченківський', 3, 'Центральна'),
#  ('Голосіївський', 2, 'Ясинуватський'),
#  ('Дніпровський', 3, 'Райдужна'),
#  ('Голосіївський', 23, 'Ломоносова'),
#  (None, 3, None),
#  (None, 15, '*** not found'),
#  ('Печерський', 7, 'Гусовського'),
#  (None, 19, 'Окіпної'),
#  ('Шевченківський', 3, 'Багговутівська'),
#  ('Печерський', 9, 'Дружби Народів'),
#  (None, 5, 'Маккейна'),
#  (None, 15, 'Маланюка'),
#  (None, 4, 'Михайла Котельникова'),
#  ("Солом'янський", 15, 'Героїв Севастополя'),
#  (None, 7, 'Маланюка'),
#  ('Печерський', 14, 'Саперне Поле'),
#  ('Оболонський', 1, 'Балтійський'),
#  ('Шевченківський', 8, 'Кудрявська'),
#  ('Святошинський', 6, 'Перемоги'),
#  ('Шевченківський', 6, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 6, 'Перемоги'),
#  ('Печерський', 16, 'Німанська'),
#  ('Дніпровський', 2, 'Каховська'),
#  ('Шевченківський', 1, 'Малопідвальна'),
#  (None, 4, 'Невська'),
#  (None, 20, 'Златоустівська'),
#  (None, 4, None),
#  ('Святошинський', 12, 'Берковецька'),
#  (None, 16, 'Бажана'),
#  ('Голосіївський, Печерський', 0, 'Антоновича'),
#  (None, 2, '*** not found'),
#  (None, 8, 'Гречка'),
#  ('Дніпровський', 2, 'Микільсько-Слобідська'),
#  ('Подільський', 15, 'Правди'),
#  (None, 22, 'Тимошенка'),
#  (None, 6, 'Павла Тичини'),
#  ('Святошинський', 4, 'Олевська'),
#  ("Солом'янський", 13, 'Освіти'),
#  (None, 3, 'Іллєнка'),
#  ('Оболонський', 25, 'Дніпровська'),
#  (None, 9, 'Івана Мазепи'),
#  (None, 6, 'Українки'),
#  (None, 27, 'Данченка'),
#  (None, 12, 'Драгомирова'),
#  (None, 9, 'Тбіліський'),
#  ('Дніпровський', 9, 'Каховська'),
#  ("Солом'янський", 0, 'Ушинського'),
#  ("Солом'янський", 0, 'Ушинського'),
#  ('Дарницький', 11, 'Урлівська'),
#  ('Подільський', 26, 'Світлицького'),
#  ('Оболонський', 21, 'Дніпровська'),
#  (None, 14, 'Липківського'),
#  ('Дніпровський', 1, 'Микільсько-Слобідська'),
#  (None, 3, 'Лобановського'),
#  ('Оболонський', 4, 'Героїв Сталінграда'),
#  ('Оболонський', 16, 'Дніпровська'),
#  ('Дарницький', 20, 'Драгоманова'),
#  (None, 11, 'Ахматової'),
#  ('Печерський', 4, 'Саперне Поле'),
#  (None, 16, 'Данченка'),
#  ('Голосіївський', 24, 'Голосіївський'),
#  ('Голосіївський', 24, 'Голосіївський'),
#  (None, 2, '*** not found'),
#  ('Шевченківський', 22, 'Глибочицька'),
#  ('Шевченківський', 10, 'Багговутівська'),
#  ('Голосіївський, Печерський, Шевченківський', 16, 'Саксаганського'),
#  (None, 4, 'Моторний'),
#  ('Оболонський', 9, 'Йорданська'),
#  ('Печерський', 12, 'Саперне Поле'),
#  (None, 18, 'Вернадського'),
#  (None, 12, 'Курбаса'),
#  ('Шевченківський', 5, 'Багговутівська'),
#  ('Подільський', 6, 'Набережно-Рибальська'),
#  ('Голосіївський, Печерський, Шевченківський', 1, 'Саксаганського'),
#  (None, 4, 'Малиновського'),
#  ("Солом'янський", 3, 'Протасів Яр'),
#  ('Печерський', 8, 'Німанська'),
#  (None, 6, 'Підвисоцького'),
#  ('Святошинський', 6, 'Зодчих'),
#  (None, 25, 'Рокосовського'),
#  ('Печерський', 11, 'Шовковична'),
#  (None, 6, 'Крушельницької'),
#  ("Солом'янський", 5, 'Новопольова'),
#  ('Дніпровський', 15, 'Визволителів'),
#  ('Дніпровський', 0, 'Сонячна'),
#  ('Шевченківський', 0, 'Сонячна'),
#  (None, 4, 'Сікорського'),
#  (None, 5, 'Радченка'),
#  ('Шевченківський', 5, 'Бульварно-Кудрявська'),
#  ("Голосіївський,Солом'янський", 20, 'Кайсарова'),
#  ('Оболонський', 13, 'Дніпровська'),
#  ('Дніпровський', 7, 'Перова'),
#  (None, 5, 'Глушкова'),
#  (None, 21, 'Рокосовського'),
#  ('Голосіївський', 21, 'Саперно-Слобідська'),
#  (None, 1, 'Миколи Кибальчича'),
#  (None, 11, 'Миколи Ушакова'),
#  ('Голосіївський, Печерський', 2, 'Антоновича'),
#  ("Солом'янський", 2, 'Богданівська'),
#  (None, 9, None),
#  (None, 15, 'Сверстюка'),
#  ('Дарницький', 14, 'Ревуцького'),
#  (None, 0, 'Ованеса Туманяна'),
#  ('Печерський', 4, 'Саперне Поле'),
#  (None, 8, 'Григоренка'),
#  (None, 16, 'Гречка'),
#  ('Оболонський', 3, 'Богатирська'),
#  ('Шевченківський', 16, 'Білоруська'),
#  ('Дніпровський', 0, 'Регенераторна'),
#  ('Дарницький', 9, 'Вишняківська'),
#  (None, 9, 'Гонгадзе'),
#  ('Подільський', 5, 'Правди'),
#  ('Святошинський', 3, 'Кольцова'),
#  ('Дніпровський', 17, 'Воскресенська'),
#  (None, 0, 'Руставелі'),
#  ('Голосіївський', 10, 'Голосіївський'),
#  ('Голосіївський', 10, 'Голосіївський'),
#  ('Дніпровський', 6, 'Комбінатна'),
#  ('Шевченківський', 9, 'Салютна'),
#  (None, 14, 'Маланюка'),
#  (None, 0, 'Ромоданова'),
#  ('Печерський', 21, 'Саперне Поле'),
#  (None, 10, 'Сім’ї Кульженків'),
#  ('Голосіївський, Печерський', 21, 'Лабораторна'),
#  ('Дарницький', 4, 'Драгоманова'),
#  (None, 5, None),
#  ('Шевченківський', 12, 'Кудрявська'),
#  ('Дніпровський', 0, 'Краківська'),
#  ('Святошинський', 6, 'Кольцова'),
#  ('Голосіївський, Печерський', 7, 'Антоновича'),
#  (None, 12, 'Лариси Руденко'),
#  (None, 12, 'Івана Пулюя'),
#  (None, 19, 'Українки'),
#  (None, 9, 'Тютюнника'),
#  (None, 14, 'Юрія Смолича'),
#  ('Оболонський', 18, 'Оболонський'),
#  (None, 23, 'Курбаса'),
#  (None, 8, 'Верховинця'),
#  ('Дарницький', 21, 'Зарічна'),
#  ('Оболонський', 3, 'Дніпровська'),
#  ('Голосіївський', 24, 'Коломийський'),
#  ('Подільський', 19, 'Правди'),
#  ('Дніпровський', 4, 'Каховська'),
#  (None, 9, 'Бойчука'),
#  ('Подільський', 3, 'Правди'),
#  (None, 5, 'Маккейна'),
#  ('Святошинський', 16, 'Перемоги'),
#  ('Шевченківський', 16, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 16, 'Перемоги'),
#  (None, 4, 'Грушевського'),
#  ('Дарницький', 3, 'Срібнокільська'),
#  ('Святошинський', 1, 'Перемоги'),
#  ('Шевченківський', 1, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 1, 'Перемоги'),
#  ('Дарницький', 9, 'Урлівська'),
#  (None, 2, 'Заболотного'),
#  ('Святошинський', 22, 'Максимовича'),
#  (None, 11, 'Бажана'),
#  (None, 9, 'Сікорського'),
#  (None, 14, 'Курбаса'),
#  ('Оболонський', 4, 'Дніпровська'),
#  (None, 10, 'Драгомирова'),
#  (None, 2, None),
#  (None, 3, 'Антонова'),
#  (None, 9, 'Бучми'),
#  ('Деснянський', 0, 'Кубанської України'),
#  ('Оболонський', 0, 'Дніпровська'),
#  (None, 2, 'Панельна'),
#  (None, 16, 'Коновальця'),
#  ('Оболонський', 8, 'Богатирська'),
#  ('Оболонський', 2, 'Оболонський'),
#  (None, 0, 'Українки'),
#  (None, 6, 'Бориса Гмирі'),
#  ('Подільський', 10, 'Правди'),
#  ('Дніпровський', 1, 'Центральна'),
#  ('Оболонський', 1, 'Центральна'),
#  ('Шевченківський', 1, 'Центральна'),
#  ("Солом'янський", 26, 'Преображенська'),
#  (None, 0, 'Коновальця'),
#  (None, 6, 'Українки'),
#  (None, 20, '*** not found'),
#  ('Голосіївський, Шевченківський, Печерський', 12, 'Велика Васильківська'),
#  (None, 15, 'Липківського'),
#  (None, 16, 'Бойчука'),
#  ('Голосіївський', 7, 'Васильківська'),
#  (None, 0, 'Данькевича'),
#  ('Оболонський', 28, 'Богатирська'),
#  (None, 16, 'Українки'),
#  (None, 7, 'Гречка'),
#  ('Печерський', 7, 'Редутна'),
#  (None, 11, 'Бориса Гмирі'),
#  (None, 6, 'Драгомирова'),
#  (None, 11, 'Туполєва'),
#  (None, 12, 'Кондратюка'),
#  ('Оболонський', 15, 'Мінський'),
#  ('Подільський', 15, 'Мінський'),
#  ('Дарницький', 4, 'Княжий Затон'),
#  ('Шевченківський', 6, 'Герцена'),
#  ('Шевченківський', 6, 'Герцена'),
#  ('Шевченківський', 6, 'Герцена'),
#  ('Оболонський', 4, 'Балтійський'),
#  (None, 8, 'Ернста'),
#  (None, 6, 'Шаповала'),
#  (None, 5, 'Городецького'),
#  (None, 18, "Сім'ї Сосніних"),
#  (None, 16, 'Івана Мазепи'),
#  (None, 5, 'Червоноткацька'),
#  (None, 6, '*** not found'),
#  ('Голосіївський', 7, 'Голосіївська'),
#  ('Голосіївський', 7, 'Голосіївська'),
#  (None, 25, '*** not found'),
#  (None, 13, 'Миколи Гулака'),
#  (None, 13, 'Івана Федорова'),
#  ('Печерський', 2, 'Саперне Поле'),
#  (None, 16, 'Миколи Хвильового'),
#  ('Шевченківський', 19, 'Паторжинського'),
#  (None, 9, 'Наумовича'),
#  (None, 3, 'Калнишевського'),
#  ('Оболонський', 1, 'Дніпровська'),
#  ('Подільський', 9, 'Електриків'),
#  ('Подільський', 9, 'Електриків'),
#  ("Солом'янський", 1, "Солом'янська"),
#  ("Солом'янський", 1, "Солом'янська"),
#  ('Дарницький', 21, 'Шевченка'),
#  ('Дарницький', 21, 'Шевченка'),
#  ('Деснянський', 21, 'Шевченка'),
#  ("Солом'янський", 21, 'Шевченка'),
#  ("Солом'янський", 21, 'Шевченка'),
#  ('Дарницький', 20, 'Озерна'),
#  ('Оболонський', 20, 'Озерна'),
#  ('Святошинський (СТ "Нивки")', 20, 'Озерна'),
#  ("Солом'янський", 20, 'Озерна'),
#  (None, 15, 'Григоренка'),
#  (None, 8, 'Антонова'),
#  ('Голосіївський', 9, 'Голосіївський'),
#  ('Голосіївський', 9, 'Голосіївський'),
#  (None, 8, 'Комарова'),
#  ("Солом'янський, Шевченківський ", 10, 'Борщагівська'),
#  ('Дарницький', 7, 'Шевченка'),
#  ('Дарницький', 7, 'Шевченка'),
#  ('Деснянський', 7, 'Шевченка'),
#  ("Солом'янський", 7, 'Шевченка'),
#  ("Солом'янський", 7, 'Шевченка'),
#  ('Святошинський', 5, 'Максимовича'),
#  ("Солом'янський", 10, 'Ковальський'),
#  (None, 2, 'Малевича'),
#  ('Деснянський', 10, 'Мічуріна'),
#  ('Оболонський', 10, 'Мічуріна'),
#  ('Печерський', 10, 'Мічуріна'),
#  ('Печерський', 10, 'Мічуріна'),
#  ("Солом'янський", 10, 'Мічуріна'),
#  (None, 3, '*** not found'),
#  ('Оболонський', 4, 'Балтійський'),
#  ('Дніпровський', 7, 'Азербайджанська'),
#  ('Дарницький', 12, 'Зарічна'),
#  (None, 16, 'Чавдар'),
#  ('Подільський', 4, 'Правди'),
#  ('Дарницький', 5, 'Урлівська'),
#  ('Дарницький', 8, 'Бориспільська'),
#  (None, 4, 'Поправки'),
#  ('Дарницький', 3, 'Бориспільська'),
#  ('Дніпровський', 3, 'Ентузіастів'),
#  ('Дарницький', 11, 'Малоземельна'),
#  ('Голосіївський, Печерський, Шевченківський', 18, 'Саксаганського'),
#  ('Оболонський', 12, 'Героїв Сталінграда'),
#  ('Святошинський', 25, 'Зодчих'),
#  (None, 4, 'Калнишевського'),
#  (None, 11, 'Філатова'),
#  ('Печерський', 1, 'Старонаводницька'),
#  (None, 8, 'Заболотного'),
#  ('Подільський', 2, 'Правди'),
#  (None, 10, '*** not found'),
#  ('Голосіївський, Печерський', 18, 'Антоновича'),
#  (None, 7, 'Шаповала'),
#  (None, 4, 'Івана Федорова'),
#  ('Шевченківський', 13, 'Деревлянська'),
#  (None, 23, 'Вільямса'),
#  ("Солом'янський", 26, 'Васильченка'),
#  ('Печерський', 9, 'Предславинська'),
#  ('Деснянський', 13, 'Крайня'),
#  ('Деснянський', 8, 'Милославська'),
#  ('Дніпровський', 9, 'Воскресенська'),
#  (None, 1, 'Маланюка'),
#  ('Оболонський', 1, 'Дніпровська'),
#  ('Шевченківський', 21, 'Пушкінська'),
#  ('Голосіївський', 13, 'Набережно-Корчуватська'),
#  ('Дарницький', 8, 'Зарічна'),
#  ('Шевченківський', 5, 'Тургенєвська'),
#  (None, 9, 'Радченка'),
#  ('Дарницький', 1, 'Зарічна'),
#  ('Голосіївський', 4, 'Метрологічна'),
#  ('Оболонський', 12, 'Йорданська'),
#  ('Святошинський', 2, 'Кольцова'),
#  ('Святошинський', 22, 'Максимовича'),
#  ('Голосіївський', 3, 'Науки'),
#  ('Голосіївський', 15, 'Саперно-Слобідська'),
#  ('Печерський', 16, 'Шовковична'),
#  ('Дарницький', 4, 'Трускавецька'),
#  (None, 4, 'Гавела'),
#  ("Шевченківський, Солом'янський", 2, 'Повітрофлотський'),
#  (None, 2, 'Запорожця'),
#  (None, 10, 'Маккейна'),
#  ('Святошинський', 13, 'Перемоги'),
#  ('Шевченківський', 13, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 13, 'Перемоги'),
#  (None, 26, 'Щербаківського'),
#  ('Дарницький', 6, 'Зарічна'),
#  ('Деснянський', 3, 'Будищанська'),
#  ('Печерський, Голосіївський, Шевченківський', 5, 'Жилянська'),
#  ('Дніпровський', 5, 'Комбінатна'),
#  ('Дарницький', 23, 'Ревуцького'),
#  (None, 18, 'Бородіна'),
#  (None, 6, 'Руставелі'),
#  ('Дарницький', 10, 'Драгоманова'),
#  ("Солом'янський", 3, 'Преображенська'),
#  ('Святошинський', 0, 'Депутатська'),
#  ('Шевченківський', 8, 'Багговутівська'),
#  (None, 10, '*** not found'),
#  (None, 6, 'Сікорського'),
#  (None, 2, 'Драгомирова'),
#  ('Шевченківський', 2, 'Коперніка'),
#  ('Голосіївський', 0, 'Васильківська'),
#  ('Шевченківський', 9, 'Глибочицька'),
#  (None, 23, 'Чавдар'),
#  ('Печерський', 25, 'Шовковична'),
#  ('Оболонський', 24, 'Дніпровська'),
#  ('Голосіївський, Печерський', 0, 'Антоновича'),
#  (None, 7, None),
#  ('Дарницький', 4, 'Славгородська'),
#  (None, 3, 'Драгомирова'),
#  ('Дарницький', 15, 'Срібнокільська'),
#  (None, 10, 'Харченка'),
#  (None, 4, 'Окіпної'),
#  ('Печерський', 0, 'Саперне Поле'),
#  (None, 11, 'Олени Теліги'),
#  (None, 10, 'Кондратюка'),
#  ('Печерський', 1, 'Мечнікова'),
#  ('Оболонський', 7, 'Героїв Сталінграда'),
#  ('Печерський', 25, 'Рибальська'),
#  ("Солом'янський", 8, 'Березова'),
#  ('Печерський', 7, 'Саперне Поле'),
#  ('Голосіївський, Печерський', 23, 'Антоновича'),
#  (None, 3, 'Маккейна'),
#  ('Печерський', 17, 'Лейпцизька'),
#  ('Дарницький', 14, 'Драгоманова'),
#  (None, 23, 'Коновальця'),
#  (None, 3, 'Василя Стуса'),
#  (None, 24, 'Тютюнника'),
#  ('Шевченківський', 15, 'Січових Стрільців'),
#  ('Дніпровський', 6, 'Райдужна'),
#  (None, 15, 'Закревського'),
#  ('Шевченківський', 9, 'Тургенєвська'),
#  ('Голосіївський', 20, 'Васильківська'),
#  (None, 20, "Зої Космодем'янської"),
#  (None, 18, 'Радченка'),
#  (None, 8, 'Сверстюка'),
#  ('Деснянський', 24, 'Милославська'),
#  ('Голосіївський', 23, 'Метрологічна'),
#  ('Голосіївський', 4, 'Деміївська'),
#  ('Голосіївський', 4, 'Деміївська'),
#  ('Святошинський', 1, 'Перемоги'),
#  ('Шевченківський', 1, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 1, 'Перемоги'),
#  ('Подільський, Оболонський', 13, 'Вишгородська'),
#  (None, 23, 'Маккейна'),
#  (None, 14, None),
#  ('Святошинський', 4, 'Перемоги'),
#  ('Шевченківський', 4, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 4, 'Перемоги'),
#  ('Оболонський', 4, 'Балтійський'),
#  ('Печерський', 1, 'Звіринецька'),
#  ('Дарницький', 13, 'Ревуцького'),
#  ('Подільський', 9, 'Правди'),
#  ('Деснянський', 15, 'Милославська'),
#  (None, 18, 'Вербицького'),
#  ("Солом'янський", 22, 'Новгородська'),
#  (None, 17, 'Бажана'),
#  ('Подільський', 11, 'Канівська'),
#  ('Святошинський', 3, 'Максимовича'),
#  (None, 11, 'Донця'),
#  (None, 4, 'Драгомирова'),
#  ('Подільський', 4, 'Тираспольська'),
#  ('Голосіївський, Печерський, Шевченківський', 3, 'Саксаганського'),
#  ('Подільський', 7, 'Тираспольська'),
#  ('Дарницький', 1, 'Зарічна'),
#  (None, 23, 'Гонгадзе'),
#  (None, 9, 'Українки'),
#  ('Подільський', 15, 'Світлицького'),
#  (None, 18, 'Воробйова'),
#  ('Дніпровський', 16, 'Каховська'),
#  ('Шевченківський', 7, 'Глибочицька'),
#  (None, 25, 'Білокур'),
#  ('Оболонський', 25, 'Балтійський'),
#  ('Голосіївський, Печерський', 7, 'Антоновича'),
#  (None, 9, 'Кондратюка'),
#  (None, 1, 'Гончара'),
#  ('Дарницький', 2, 'Ревуцького'),
#  (None, 8, '*** not found'),
#  ('Дарницький', 4, 'Драгоманова'),
#  (None, 24, 'Сім’ї Кульженків'),
#  (None, 13, 'Панельна'),
#  (None, 4, 'Вільямса'),
#  ('Голосіївський', 2, 'Голосіївська'),
#  ('Голосіївський', 2, 'Голосіївська'),
#  ('Оболонський', 18, 'Оболонський'),
#  ("Солом'янський", 6, 'Миколи Голего'),
#  ('Оболонський', 17, 'Дніпровська'),
#  (None, 11, 'Малиновського'),
#  ('Шевченківський', 9, 'Назарівська'),
#  ('Шевченківський', 23, 'Гоголівська'),
#  ('Шевченківський', 4, 'Дорогожицька'),
#  ('Оболонський', 15, 'Петропавлівська'),
#  ('Подільський', 15, 'Петропавлівська'),
#  (None, 6, 'Грушевського'),
#  (None, 21, 'Іллєнка'),
#  (None, 10, 'Липківського'),
#  ("Солом'янський", 8, 'Ушинського'),
#  ("Солом'янський", 8, 'Ушинського'),
#  ('Дарницький', 10, 'Польова'),
#  ('Деснянський', 10, 'Польова'),
#  ("Солом'янський", 10, 'Польова'),
#  ('Печерський', 5, 'Саперне Поле'),
#  (None, 6, 'Панельна'),
#  (None, 4, 'Коновальця'),
#  (None, 3, 'Хмельницького'),
#  (None, 9, 'Маккейна'),
#  ('Голосіївський, Печерський', 24, 'Антоновича'),
#  ('Дарницький', 5, 'Толстого'),
#  ('Печерський', 9, 'Дружби Народів'),
#  ('Оболонський', 17, 'Оболонський'),
#  ('Шевченківський', 17, 'Багговутівська'),
#  (None, 20, 'Антонова'),
#  ('Голосіївський, Шевченківський', 4, 'Володимирська'),
#  (None, 22, 'Українки'),
#  (None, 3, 'Сім’ї Кульженків'),
#  (None, 1, 'Коновальця'),
#  (None, 28, 'Мирного'),
#  ('Печерський', 0, 'Московська'),
#  ("Солом'янський", 0, 'Московська'),
#  ('Святошинський', 5, 'Жмеринська'),
#  (None, 12, 'Бойчука'),
#  (None, 5, 'Липківського'),
#  ('Печерський', 8, 'Лабораторний'),
#  ('Печерський', 0, 'Інститутська'),
#  (None, 7, 'Українки'),
#  ('Печерський, Шевченківський', 3, 'Хрещатик'),
#  ('Оболонський', 20, 'Дніпровська'),
#  ('Дарницький', 14, 'Осокорська'),
#  ('Печерський', 2, 'Саперне Поле'),
#  (None, 13, 'Комарова'),
#  (None, 0, 'Драгомирова'),
#  ('Дарницький', 3, 'Срібнокільська'),
#  ("Солом'янський", 22, 'Чоколівський'),
#  ('Печерський', 4, 'Звіринецька'),
#  ('Подільський, Оболонський', 7, 'Вишгородська'),
#  (None, 11, 'Драгомирова'),
#  ('Оболонський', 0, 'Героїв Сталінграда'),
#  ('Деснянський', 0, 'Будівельників'),
#  ('Дніпровський', 0, 'Будівельників'),
#  ('Дніпровський', 0, 'Будівельників'),
#  ('Святошинський', 0, 'Будівельників'),
#  (None, 2, 'Іллєнка'),
#  ('Дарницький', 3, 'Урлівська'),
#  ('Дарницький', 9, 'Сормовська'),
#  ('Подільський', 0, 'Правди'),
#  ('Святошинський', 7, 'Верховинна'),
#  (None, 17, 'Вербицького'),
#  (None, 1, '*** not found'),
#  ('Голосіївський, Шевченківський, Печерський', 15, 'Велика Васильківська'),
#  (None, 11, 'Бойчука'),
#  (None, 9, 'Лобановського'),
#  (None, 0, 'Миколи Шепелєва'),
#  ('Печерський', 21, 'Кропивницького'),
#  ('Дарницький', 7, 'Трускавецька'),
#  ('Голосіївський', 28, 'Голосіївська'),
#  ('Голосіївський', 28, 'Голосіївська'),
#  (None, 4, 'Маланюка'),
#  (None, 4, 'Драгомирова'),
#  ('Святошинський', 24, 'Юнацька'),
#  ("Солом'янський", 24, 'Юнацька'),
#  ('Святошинський', 5, 'Максимовича'),
#  (None, 3, 'Комарова'),
#  ('Шевченківський', 1, 'Багговутівська'),
#  (None, 7, None),
#  ('Голосіївський', 10, 'Костанайська'),
#  ('Дарницький', 10, 'Срібнокільська'),
#  (None, 1, 'Курчатова'),
#  ('Печерський', 4, 'Гусовського'),
#  (None, 5, 'Українки'),
#  ('Дарницький', 23, 'Драгоманова'),
#  ('Оболонський', 18, 'Дніпровська'),
#  (None, 9, 'Заболотного'),
#  (None, 4, 'Заболотного'),
#  ('Святошинський', 7, 'Перемоги'),
#  ('Шевченківський', 7, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 7, 'Перемоги'),
#  (None, 3, 'Сверстюка'),
#  (None, 2, 'Липківського'),
#  (None, 16, 'Маккейна'),
#  ('Оболонський', 12, 'Дніпровська'),
#  ('Деснянський', 4, 'Волгоградська'),
#  ("Солом'янський", 4, 'Волгоградська'),
#  ("Солом'янський", 5, 'Новопольова'),
#  ('Дарницький', 3, 'Драгоманова'),
#  (None, 16, 'Лебедєва'),
#  (None, 3, '*** not found'),
#  (None, 10, 'Драгомирова'),
#  ('Печерський', 22, 'Лейпцизька'),
#  ('Шевченківський', 10, 'Глибочицька'),
#  ('Шевченківський', 4, 'Салютна'),
#  ('Голосіївський', 0, 'Метрологічна'),
#  ('Подільський', 18, 'Північно-Сирецька'),
#  ('Подільський', 1, 'Правди'),
#  (None, 1, 'Вернадського'),
#  (None, 6, 'Пчілки'),
#  ('Печерський', 12, 'Лейпцизька'),
#  ('Печерський, Шевченківський', 0, 'Басейна'),
#  (None, 8, 'Шаповала'),
#  ('Оболонський', 2, 'Бережанська'),
#  (None, 17, 'Бойчука'),
#  ('Святошинський', 6, 'Перемоги'),
#  ('Шевченківський', 6, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 6, 'Перемоги'),
#  (None, 0, 'Івана Федорова'),
#  ('Голосіївський, Печерський', 18, 'Антоновича'),
#  (None, 4, 'Вільямса'),
#  (None, 14, 'Бойчука'),
#  ('Святошинський', 2, 'Перемоги'),
#  ('Шевченківський', 2, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 2, 'Перемоги'),
#  ('Голосіївський, Печерський', 9, 'Ковпака'),
#  ('Дніпровський', 3, 'Русанівський'),
#  (None, 0, 'Українки'),
#  ('Дніпровський', 5, 'Празька'),
#  (None, 15, 'Гончара'),
#  (None, 24, 'Маккейна'),
#  ('Оболонський', 4, 'Балтійський'),
#  ('Шевченківський', 2, 'Білоруська'),
#  ('Дарницький', 9, 'Драгоманова'),
#  (None, 14, 'Липківського'),
#  ('Печерський', 12, 'Новогоспітальна'),
#  (None, 3, 'Радченка'),
#  (None, 9, 'Богомольця'),
#  (None, 9, 'Донця'),
#  ('Оболонський', 3, 'Оболонський'),
#  ('Подільський', 9, 'Щекавицька'),
#  ('Подільський', 9, 'Щекавицька'),
#  ('Деснянський', 22, 'Пожарського'),
#  ('Дніпровський', 22, 'Пожарського'),
#  ('Подільський', 25, 'Полкова'),
#  (None, 9, 'Донця'),
#  (None, 3, 'Палладіна'),
#  (None, 17, 'Бойчука'),
#  (None, 0, 'Липківського'),
#  ('Шевченківський', 21, 'Павлівська'),
#  (None, 2, 'Івашкевича'),
#  ("Солом'янський", 15, 'Іскрівська'),
#  ('Святошинський', 1, 'Максимовича'),
#  (None, 6, '*** not found'),
#  (None, 18, 'Драгомирова'),
#  ('Голосіївський', 22, 'Теремківська'),
#  ('Дарницький', 19, 'Осокорська'),
#  ('Подільський', 24, 'Дмитрівська'),
#  ('Шевченківський', 24, 'Дмитрівська'),
#  (None, 5, 'Кондратюка'),
#  ('Дніпровський', 22, 'Регенераторна'),
#  (None, 3, None),
#  ('Шевченківський', 25, 'Глибочицька'),
#  ('Оболонський', 12, 'Героїв Сталінграда'),
#  ("Солом'янський, Шевченківський ", 0, 'Борщагівська'),
#  ('Дарницький', 21, 'Ревуцького'),
#  ('Святошинський', 19, 'Юнацька'),
#  ("Солом'янський", 19, 'Юнацька'),
#  (None, 21, 'Заболотного'),
#  ('Оболонський', 8, 'Автозаводська'),
#  (None, 17, 'Заболотного'),
#  ('Голосіївський, Печерський, Шевченківський', 0, 'Саксаганського'),
#  ('Дарницький', 6, 'Зарічна'),
#  (None, 20, '*** not found'),
#  (None, 8, 'Невська'),
#  ('Оболонський', 12, 'Героїв Сталінграда'),
#  ('Дарницький', 0, 'Вишняківська'),
#  (None, 8, 'Драгомирова'),
#  (None, 15, 'Драгомирова'),
#  (None, 1, 'Гавела'),
#  ('Дарницький', 18, 'Здолбунівська'),
#  (None, 15, 'Драгомирова'),
#  ('Печерський', 2, 'Мечнікова'),
#  (None, 0, '*** not found'),
#  ('Святошинський', 2, 'Максимовича'),
#  ('Шевченківський', 3, 'Багговутівська'),
#  ('Шевченківський', 24, 'Шолуденка'),
#  ('Подільський', 5, 'Щекавицька'),
#  ('Подільський', 5, 'Щекавицька'),
#  (None, 4, 'Коласа'),
#  (None, 15, '*** not found'),
#  (None, 6, '*** not found'),
#  ('Святошинський', 9, 'Перемоги'),
#  ('Шевченківський', 9, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 9, 'Перемоги'),
#  (None, 23, '*** not found'),
#  (None, 29, 'Наумова'),
#  ('Святошинський', 5, 'Перемоги'),
#  ('Шевченківський', 5, 'Перемоги'),
#  ("Шевченківський, Святошинський, Солом'янський", 5, 'Перемоги'),
#  ('Голосіївський, Шевченківський, Печерський', 19, 'Велика Васильківська'),
#  (None, 11, 'Червоноткацька'),
#  ('Подільський, Оболонський', 7, 'Вишгородська')]

# %%
# створити запит для наповнення таблиці `result` результатом запиту на об'єднання
stmt_insert = ("INSERT INTO result " + stmt_join)

# %%
# виконати запит на заповнення
cur.execute(stmt_insert)

# %%
# сберегти вміст створеної таблиці у вигляді списка
result_list = cur.execute("SELECT * FROM result").fetchall()

_ = [print(x) for x in result_list]
# Out:
# (None, '21', 'Омеляновича-Павленка')
# (None, '11', None)
# (None, '5', 'Ованеса Туманяна')
# ('Оболонський', '5', 'Петропавлівська')
# ('Подільський', '5', 'Петропавлівська')
# ('Оболонський', '2', 'Дніпровська')
# ('Голосіївський, Печерський, Шевченківський', '2', 'Саксаганського')
# (None, '21', 'Івана Мазепи')
# ('Оболонський', '4', 'Дніпровська')
# ('Голосіївський, Печерський', '6', 'Ділова')
# (None, '2', 'Новодарницька')
# ('Дарницький', '8', 'Ревуцького')
# (None, '2', 'Липківського')
# (None, '13', 'Бендукідзе')
# ('Подільський', '12', 'Введенська')
# ('Печерський', '12', 'Виноградний')
# ("Голосіївський,Солом'янський", '5', 'Кайсарова')
# (None, '16', 'Ахматової')
# (None, '4', 'Радченка')
# ('Оболонський', '3', 'Дніпровська')
# ('Голосіївський, Печерський', '21', 'Ділова')
# ('Дарницький', '3', 'Бориспільська')
# ('Печерський', '8', 'Болсуновська')
# (None, '5', 'Українки')
# (None, '5', 'Антонова')
# (None, '3', 'Омеляновича-Павленка')
# (None, '7', None)
# (None, '14', 'Ованеса Туманяна')
# ('Оболонський', '6', 'Петропавлівська')
# ('Подільський', '6', 'Петропавлівська')
# ('Оболонський', '19', 'Дніпровська')
# ('Голосіївський, Печерський, Шевченківський', '1', 'Саксаганського')
# (None, '7', 'Івана Мазепи')
# ('Оболонський', '12', 'Дніпровська')
# ('Голосіївський, Печерський', '6', 'Ділова')
# (None, '1', 'Новодарницька')
# ('Дарницький', '24', 'Ревуцького')
# (None, '11', 'Липківського')
# (None, '5', 'Бендукідзе')
# ('Подільський', '9', 'Введенська')
# ('Печерський', '3', 'Виноградний')
# ("Голосіївський,Солом'янський", '15', 'Кайсарова')
# (None, '3', 'Ахматової')
# (None, '15', 'Радченка')
# ('Оболонський', '9', 'Дніпровська')
# ('Голосіївський, Печерський', '17', 'Ділова')
# ('Дарницький', '22', 'Бориспільська')
# ('Печерський', '1', 'Болсуновська')
# (None, '14', 'Українки')
# (None, '5', 'Антонова')
# ('Голосіївський', '12', 'Науки')
# ('Голосіївський', '4', 'Метрологічна')
# ('Печерський', '5', 'Дружби Народів')
# (None, '16', '*** not found')
# (None, '14', 'Драгомирова')
# (None, '13', 'Данченка')
# ('Голосіївський', '3', 'Кримська')
# ("Солом'янський", '10', 'Новопольова')
# (None, '7', 'Туполєва')
# (None, '6', '*** not found')
# ('Оболонський', '9', 'Дніпровська')
# ('Святошинський', '10', 'Перемоги')
# ('Шевченківський', '10', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '10', 'Перемоги')
# (None, '9', 'Івана Федорова')
# ('Деснянський, Дніпровський', '2', 'Братиславська')
# (None, '3', '*** not found')
# (None, '3', 'Червоноткацька')
# (None, '5', 'Златоустівська')
# (None, '0', 'Бойченка')
# ('Дарницький', '29', 'Трускавецька')
# ('Дніпровський', '2', 'Каховська')
# (None, '16', 'Лобановського')
# (None, '4', '*** not found')
# (None, '3', 'Курчатова')
# ('Голосіївський', '21', 'Голосіївська')
# ('Голосіївський', '21', 'Голосіївська')
# ('Подільський', '12', 'Тираспольська')
# ('Печерський', '4', 'Лаврська')
# ('Подільський', '5', 'Правди')
# (None, '16', 'Миколайчука')
# (None, '14', 'Порика')
# (None, '13', 'Червоноткацька')
# (None, '3', 'Маккейна')
# ('Оболонський', '10', 'Йорданська')
# (None, '7', 'Тютюнника')
# ('Дніпровський', '6', 'Регенераторна')
# ('Дарницький', '9', 'Зарічна')
# (None, '10', 'Заболотного')
# ('Дніпровський, Деснянський', '9', 'Курнатовського')
# ('Печерський', '2', 'Інститутська')
# (None, '3', 'Маланюка')
# (None, '3', 'Гречка')
# (None, '5', 'Липківського')
# (None, '0', 'Маккейна')
# (None, '29', 'Григоренка')
# (None, '2', 'Коновальця')
# (None, '16', 'Закревського')
# (None, '4', '*** not found')
# ('Печерський', '3', 'Старонаводницька')
# (None, '21', 'Маланюка')
# ('Печерський', '6', 'Заньковецької')
# ('Шевченківський', '7', 'Кудрявська')
# (None, '10', None)
# (None, '2', 'Українки')
# (None, '5', None)
# ('Деснянський', '2', 'Милославська')
# (None, '2', 'Донця')
# (None, '23', 'Верховинця')
# ('Оболонський', '2', 'Героїв Дніпра')
# ('Дніпровський', '7', 'Каховська')
# ('Дніпровський', '11', 'Каховська')
# ('Дарницький', '4', 'Вишняківська')
# (None, '6', 'Липська')
# (None, '9', 'Сверстюка')
# (None, '4', 'Драгомирова')
# ('Дарницький', '18', 'Причальна')
# ('Печерський', '5', 'Болсуновська')
# ("Шевченківський, Солом'янський", '3', 'Повітрофлотський')
# ('Дарницький', '3', 'Драгоманова')
# (None, '5', 'Григоренка')
# ('Оболонський', '23', 'Дніпровська')
# (None, '3', 'Жабаєва')
# (None, '8', 'Філатова')
# ('Подільський', '9', 'Правди')
# ('Шевченківський', '3', 'Малопідвальна')
# (None, '3', 'Бойчука')
# ('Дарницький', '7', 'Зарічна')
# ('Печерський', '5', 'Предславинська')
# (None, '3', 'Івана Мазепи')
# (None, '11', 'Радченка')
# ('Печерський', '17', 'Лабораторний')
# (None, '19', 'Конєва')
# (None, '4', 'Шаповала')
# ('Оболонський', '19', 'Дніпровська')
# ('Дарницький', '6', 'Клеманська')
# (None, '4', 'Григоренка')
# (None, '23', 'Туполєва')
# (None, '9', 'Хмельницького')
# ('Печерський', '3', 'Саперне Поле')
# ('Оболонський', '3', 'Героїв Сталінграда')
# ('Оболонський', '12', 'Дніпровська')
# ('Голосіївський', '2', 'Тарасівська')
# ('Дніпровський', '6', 'Краківська')
# ('Святошинський', '4', 'Юнацька')
# ("Солом'янський", '4', 'Юнацька')
# ('Дарницький', '10', 'Клеманська')
# ('Оболонський', '8', 'Героїв Сталінграда')
# (None, '2', 'Драгомирова')
# (None, '3', '*** not found')
# ('Дарницький', '23', 'Драгоманова')
# (None, '2', 'Українки')
# (None, '7', 'Тимошенка')
# ('Деснянський', '3', 'Маяковського')
# ('Подільський', '3', 'Дмитрівська')
# ('Шевченківський', '3', 'Дмитрівська')
# (None, '2', 'Курбаса')
# (None, '11', 'Комарова')
# ('Дарницький', '21', 'Драгоманова')
# (None, '2', 'Драгомирова')
# (None, '7', 'Моторний')
# ('Деснянський', '10', 'Милославська')
# (None, '13', 'Бойчука')
# (None, '22', 'Закревського')
# (None, '5', 'Івана Федорова')
# (None, '17', 'Філатова')
# ('Святошинський', '13', 'Перемоги')
# ('Шевченківський', '13', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '13', 'Перемоги')
# ('Деснянський, Дніпровський', '6', 'Миропільська')
# (None, '11', 'Григоренка')
# ('Святошинський', '9', 'Юнацька')
# ("Солом'янський", '9', 'Юнацька')
# ('Подільський, Оболонський', '1', 'Вишгородська')
# ('Святошинський', '1', 'Жолудєва')
# ('Шевченківський', '17', 'Павлівська')
# ('Голосіївський', '11', 'Голосіївський')
# ('Голосіївський', '11', 'Голосіївський')
# ('Дарницький', '4', 'Осокорська')
# ('Подільський, Оболонський', '10', 'Вишгородська')
# (None, '12', 'Драгомирова')
# (None, '5', 'Тютюнника')
# (None, '5', 'Маккейна')
# (None, '7', 'Івана Мазепи')
# ('Оболонський', '9', 'Героїв Сталінграда')
# (None, '23', 'Липківського')
# (None, '15', '*** not found')
# (None, '12', 'Коновальця')
# ('Святошинський', '22', 'Максимовича')
# ('Дарницький', '6', 'Зарічна')
# ('Голосіївський', '6', 'Голосіївська')
# ('Голосіївський', '6', 'Голосіївська')
# ('Голосіївський', '5', 'Ясинуватський')
# (None, '8', '*** not found')
# (None, '0', 'Колоса')
# ('Подільський', '2', 'Правди')
# ('Голосіївський, Шевченківський, Печерський', '2', 'Велика Васильківська')
# ('Голосіївський', '1', 'Голосіївський')
# ('Голосіївський', '1', 'Голосіївський')
# (None, '7', '*** not found')
# (None, '2', 'Бойчука')
# ('Дніпровський', '3', 'Центральна')
# ('Оболонський', '3', 'Центральна')
# ('Шевченківський', '3', 'Центральна')
# ('Голосіївський', '2', 'Ясинуватський')
# ('Дніпровський', '3', 'Райдужна')
# ('Голосіївський', '23', 'Ломоносова')
# (None, '3', None)
# (None, '15', '*** not found')
# ('Печерський', '7', 'Гусовського')
# (None, '19', 'Окіпної')
# ('Шевченківський', '3', 'Багговутівська')
# ('Печерський', '9', 'Дружби Народів')
# (None, '5', 'Маккейна')
# (None, '15', 'Маланюка')
# (None, '4', 'Михайла Котельникова')
# ("Солом'янський", '15', 'Героїв Севастополя')
# (None, '7', 'Маланюка')
# ('Печерський', '14', 'Саперне Поле')
# ('Оболонський', '1', 'Балтійський')
# ('Шевченківський', '8', 'Кудрявська')
# ('Святошинський', '6', 'Перемоги')
# ('Шевченківський', '6', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '6', 'Перемоги')
# ('Печерський', '16', 'Німанська')
# ('Дніпровський', '2', 'Каховська')
# ('Шевченківський', '1', 'Малопідвальна')
# (None, '4', 'Невська')
# (None, '20', 'Златоустівська')
# (None, '4', None)
# ('Святошинський', '12', 'Берковецька')
# (None, '16', 'Бажана')
# ('Голосіївський, Печерський', '0', 'Антоновича')
# (None, '2', '*** not found')
# (None, '8', 'Гречка')
# ('Дніпровський', '2', 'Микільсько-Слобідська')
# ('Подільський', '15', 'Правди')
# (None, '22', 'Тимошенка')
# (None, '6', 'Павла Тичини')
# ('Святошинський', '4', 'Олевська')
# ("Солом'янський", '13', 'Освіти')
# (None, '3', 'Іллєнка')
# ('Оболонський', '25', 'Дніпровська')
# (None, '9', 'Івана Мазепи')
# (None, '6', 'Українки')
# (None, '27', 'Данченка')
# (None, '12', 'Драгомирова')
# (None, '9', 'Тбіліський')
# ('Дніпровський', '9', 'Каховська')
# ("Солом'янський", '0', 'Ушинського')
# ("Солом'янський", '0', 'Ушинського')
# ('Дарницький', '11', 'Урлівська')
# ('Подільський', '26', 'Світлицького')
# ('Оболонський', '21', 'Дніпровська')
# (None, '14', 'Липківського')
# ('Дніпровський', '1', 'Микільсько-Слобідська')
# (None, '3', 'Лобановського')
# ('Оболонський', '4', 'Героїв Сталінграда')
# ('Оболонський', '16', 'Дніпровська')
# ('Дарницький', '20', 'Драгоманова')
# (None, '11', 'Ахматової')
# ('Печерський', '4', 'Саперне Поле')
# (None, '16', 'Данченка')
# ('Голосіївський', '24', 'Голосіївський')
# ('Голосіївський', '24', 'Голосіївський')
# (None, '2', '*** not found')
# ('Шевченківський', '22', 'Глибочицька')
# ('Шевченківський', '10', 'Багговутівська')
# ('Голосіївський, Печерський, Шевченківський', '16', 'Саксаганського')
# (None, '4', 'Моторний')
# ('Оболонський', '9', 'Йорданська')
# ('Печерський', '12', 'Саперне Поле')
# (None, '18', 'Вернадського')
# (None, '12', 'Курбаса')
# ('Шевченківський', '5', 'Багговутівська')
# ('Подільський', '6', 'Набережно-Рибальська')
# ('Голосіївський, Печерський, Шевченківський', '1', 'Саксаганського')
# (None, '4', 'Малиновського')
# ("Солом'янський", '3', 'Протасів Яр')
# ('Печерський', '8', 'Німанська')
# (None, '6', 'Підвисоцького')
# ('Святошинський', '6', 'Зодчих')
# (None, '25', 'Рокосовського')
# ('Печерський', '11', 'Шовковична')
# (None, '6', 'Крушельницької')
# ("Солом'янський", '5', 'Новопольова')
# ('Дніпровський', '15', 'Визволителів')
# ('Дніпровський', '0', 'Сонячна')
# ('Шевченківський', '0', 'Сонячна')
# (None, '4', 'Сікорського')
# (None, '5', 'Радченка')
# ('Шевченківський', '5', 'Бульварно-Кудрявська')
# ("Голосіївський,Солом'янський", '20', 'Кайсарова')
# ('Оболонський', '13', 'Дніпровська')
# ('Дніпровський', '7', 'Перова')
# (None, '5', 'Глушкова')
# (None, '21', 'Рокосовського')
# ('Голосіївський', '21', 'Саперно-Слобідська')
# (None, '1', 'Миколи Кибальчича')
# (None, '11', 'Миколи Ушакова')
# ('Голосіївський, Печерський', '2', 'Антоновича')
# ("Солом'янський", '2', 'Богданівська')
# (None, '9', None)
# (None, '15', 'Сверстюка')
# ('Дарницький', '14', 'Ревуцького')
# (None, '0', 'Ованеса Туманяна')
# ('Печерський', '4', 'Саперне Поле')
# (None, '8', 'Григоренка')
# (None, '16', 'Гречка')
# ('Оболонський', '3', 'Богатирська')
# ('Шевченківський', '16', 'Білоруська')
# ('Дніпровський', '0', 'Регенераторна')
# ('Дарницький', '9', 'Вишняківська')
# (None, '9', 'Гонгадзе')
# ('Подільський', '5', 'Правди')
# ('Святошинський', '3', 'Кольцова')
# ('Дніпровський', '17', 'Воскресенська')
# (None, '0', 'Руставелі')
# ('Голосіївський', '10', 'Голосіївський')
# ('Голосіївський', '10', 'Голосіївський')
# ('Дніпровський', '6', 'Комбінатна')
# ('Шевченківський', '9', 'Салютна')
# (None, '14', 'Маланюка')
# (None, '0', 'Ромоданова')
# ('Печерський', '21', 'Саперне Поле')
# (None, '10', 'Сім’ї Кульженків')
# ('Голосіївський, Печерський', '21', 'Лабораторна')
# ('Дарницький', '4', 'Драгоманова')
# (None, '5', None)
# ('Шевченківський', '12', 'Кудрявська')
# ('Дніпровський', '0', 'Краківська')
# ('Святошинський', '6', 'Кольцова')
# ('Голосіївський, Печерський', '7', 'Антоновича')
# (None, '12', 'Лариси Руденко')
# (None, '12', 'Івана Пулюя')
# (None, '19', 'Українки')
# (None, '9', 'Тютюнника')
# (None, '14', 'Юрія Смолича')
# ('Оболонський', '18', 'Оболонський')
# (None, '23', 'Курбаса')
# (None, '8', 'Верховинця')
# ('Дарницький', '21', 'Зарічна')
# ('Оболонський', '3', 'Дніпровська')
# ('Голосіївський', '24', 'Коломийський')
# ('Подільський', '19', 'Правди')
# ('Дніпровський', '4', 'Каховська')
# (None, '9', 'Бойчука')
# ('Подільський', '3', 'Правди')
# (None, '5', 'Маккейна')
# ('Святошинський', '16', 'Перемоги')
# ('Шевченківський', '16', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '16', 'Перемоги')
# (None, '4', 'Грушевського')
# ('Дарницький', '3', 'Срібнокільська')
# ('Святошинський', '1', 'Перемоги')
# ('Шевченківський', '1', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '1', 'Перемоги')
# ('Дарницький', '9', 'Урлівська')
# (None, '2', 'Заболотного')
# ('Святошинський', '22', 'Максимовича')
# (None, '11', 'Бажана')
# (None, '9', 'Сікорського')
# (None, '14', 'Курбаса')
# ('Оболонський', '4', 'Дніпровська')
# (None, '10', 'Драгомирова')
# (None, '2', None)
# (None, '3', 'Антонова')
# (None, '9', 'Бучми')
# ('Деснянський', '0', 'Кубанської України')
# ('Оболонський', '0', 'Дніпровська')
# (None, '2', 'Панельна')
# (None, '16', 'Коновальця')
# ('Оболонський', '8', 'Богатирська')
# ('Оболонський', '2', 'Оболонський')
# (None, '0', 'Українки')
# (None, '6', 'Бориса Гмирі')
# ('Подільський', '10', 'Правди')
# ('Дніпровський', '1', 'Центральна')
# ('Оболонський', '1', 'Центральна')
# ('Шевченківський', '1', 'Центральна')
# ("Солом'янський", '26', 'Преображенська')
# (None, '0', 'Коновальця')
# (None, '6', 'Українки')
# (None, '20', '*** not found')
# ('Голосіївський, Шевченківський, Печерський', '12', 'Велика Васильківська')
# (None, '15', 'Липківського')
# (None, '16', 'Бойчука')
# ('Голосіївський', '7', 'Васильківська')
# (None, '0', 'Данькевича')
# ('Оболонський', '28', 'Богатирська')
# (None, '16', 'Українки')
# (None, '7', 'Гречка')
# ('Печерський', '7', 'Редутна')
# (None, '11', 'Бориса Гмирі')
# (None, '6', 'Драгомирова')
# (None, '11', 'Туполєва')
# (None, '12', 'Кондратюка')
# ('Оболонський', '15', 'Мінський')
# ('Подільський', '15', 'Мінський')
# ('Дарницький', '4', 'Княжий Затон')
# ('Шевченківський', '6', 'Герцена')
# ('Шевченківський', '6', 'Герцена')
# ('Шевченківський', '6', 'Герцена')
# ('Оболонський', '4', 'Балтійський')
# (None, '8', 'Ернста')
# (None, '6', 'Шаповала')
# (None, '5', 'Городецького')
# (None, '18', "Сім'ї Сосніних")
# (None, '16', 'Івана Мазепи')
# (None, '5', 'Червоноткацька')
# (None, '6', '*** not found')
# ('Голосіївський', '7', 'Голосіївська')
# ('Голосіївський', '7', 'Голосіївська')
# (None, '25', '*** not found')
# (None, '13', 'Миколи Гулака')
# (None, '13', 'Івана Федорова')
# ('Печерський', '2', 'Саперне Поле')
# (None, '16', 'Миколи Хвильового')
# ('Шевченківський', '19', 'Паторжинського')
# (None, '9', 'Наумовича')
# (None, '3', 'Калнишевського')
# ('Оболонський', '1', 'Дніпровська')
# ('Подільський', '9', 'Електриків')
# ('Подільський', '9', 'Електриків')
# ("Солом'янський", '1', "Солом'янська")
# ("Солом'янський", '1', "Солом'янська")
# ('Дарницький', '21', 'Шевченка')
# ('Дарницький', '21', 'Шевченка')
# ('Деснянський', '21', 'Шевченка')
# ("Солом'янський", '21', 'Шевченка')
# ("Солом'янський", '21', 'Шевченка')
# ('Дарницький', '20', 'Озерна')
# ('Оболонський', '20', 'Озерна')
# ('Святошинський (СТ "Нивки")', '20', 'Озерна')
# ("Солом'янський", '20', 'Озерна')
# (None, '15', 'Григоренка')
# (None, '8', 'Антонова')
# ('Голосіївський', '9', 'Голосіївський')
# ('Голосіївський', '9', 'Голосіївський')
# (None, '8', 'Комарова')
# ("Солом'янський, Шевченківський ", '10', 'Борщагівська')
# ('Дарницький', '7', 'Шевченка')
# ('Дарницький', '7', 'Шевченка')
# ('Деснянський', '7', 'Шевченка')
# ("Солом'янський", '7', 'Шевченка')
# ("Солом'янський", '7', 'Шевченка')
# ('Святошинський', '5', 'Максимовича')
# ("Солом'янський", '10', 'Ковальський')
# (None, '2', 'Малевича')
# ('Деснянський', '10', 'Мічуріна')
# ('Оболонський', '10', 'Мічуріна')
# ('Печерський', '10', 'Мічуріна')
# ('Печерський', '10', 'Мічуріна')
# ("Солом'янський", '10', 'Мічуріна')
# (None, '3', '*** not found')
# ('Оболонський', '4', 'Балтійський')
# ('Дніпровський', '7', 'Азербайджанська')
# ('Дарницький', '12', 'Зарічна')
# (None, '16', 'Чавдар')
# ('Подільський', '4', 'Правди')
# ('Дарницький', '5', 'Урлівська')
# ('Дарницький', '8', 'Бориспільська')
# (None, '4', 'Поправки')
# ('Дарницький', '3', 'Бориспільська')
# ('Дніпровський', '3', 'Ентузіастів')
# ('Дарницький', '11', 'Малоземельна')
# ('Голосіївський, Печерський, Шевченківський', '18', 'Саксаганського')
# ('Оболонський', '12', 'Героїв Сталінграда')
# ('Святошинський', '25', 'Зодчих')
# (None, '4', 'Калнишевського')
# (None, '11', 'Філатова')
# ('Печерський', '1', 'Старонаводницька')
# (None, '8', 'Заболотного')
# ('Подільський', '2', 'Правди')
# (None, '10', '*** not found')
# ('Голосіївський, Печерський', '18', 'Антоновича')
# (None, '7', 'Шаповала')
# (None, '4', 'Івана Федорова')
# ('Шевченківський', '13', 'Деревлянська')
# (None, '23', 'Вільямса')
# ("Солом'янський", '26', 'Васильченка')
# ('Печерський', '9', 'Предславинська')
# ('Деснянський', '13', 'Крайня')
# ('Деснянський', '8', 'Милославська')
# ('Дніпровський', '9', 'Воскресенська')
# (None, '1', 'Маланюка')
# ('Оболонський', '1', 'Дніпровська')
# ('Шевченківський', '21', 'Пушкінська')
# ('Голосіївський', '13', 'Набережно-Корчуватська')
# ('Дарницький', '8', 'Зарічна')
# ('Шевченківський', '5', 'Тургенєвська')
# (None, '9', 'Радченка')
# ('Дарницький', '1', 'Зарічна')
# ('Голосіївський', '4', 'Метрологічна')
# ('Оболонський', '12', 'Йорданська')
# ('Святошинський', '2', 'Кольцова')
# ('Святошинський', '22', 'Максимовича')
# ('Голосіївський', '3', 'Науки')
# ('Голосіївський', '15', 'Саперно-Слобідська')
# ('Печерський', '16', 'Шовковична')
# ('Дарницький', '4', 'Трускавецька')
# (None, '4', 'Гавела')
# ("Шевченківський, Солом'янський", '2', 'Повітрофлотський')
# (None, '2', 'Запорожця')
# (None, '10', 'Маккейна')
# ('Святошинський', '13', 'Перемоги')
# ('Шевченківський', '13', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '13', 'Перемоги')
# (None, '26', 'Щербаківського')
# ('Дарницький', '6', 'Зарічна')
# ('Деснянський', '3', 'Будищанська')
# ('Печерський, Голосіївський, Шевченківський', '5', 'Жилянська')
# ('Дніпровський', '5', 'Комбінатна')
# ('Дарницький', '23', 'Ревуцького')
# (None, '18', 'Бородіна')
# (None, '6', 'Руставелі')
# ('Дарницький', '10', 'Драгоманова')
# ("Солом'янський", '3', 'Преображенська')
# ('Святошинський', '0', 'Депутатська')
# ('Шевченківський', '8', 'Багговутівська')
# (None, '10', '*** not found')
# (None, '6', 'Сікорського')
# (None, '2', 'Драгомирова')
# ('Шевченківський', '2', 'Коперніка')
# ('Голосіївський', '0', 'Васильківська')
# ('Шевченківський', '9', 'Глибочицька')
# (None, '23', 'Чавдар')
# ('Печерський', '25', 'Шовковична')
# ('Оболонський', '24', 'Дніпровська')
# ('Голосіївський, Печерський', '0', 'Антоновича')
# (None, '7', None)
# ('Дарницький', '4', 'Славгородська')
# (None, '3', 'Драгомирова')
# ('Дарницький', '15', 'Срібнокільська')
# (None, '10', 'Харченка')
# (None, '4', 'Окіпної')
# ('Печерський', '0', 'Саперне Поле')
# (None, '11', 'Олени Теліги')
# (None, '10', 'Кондратюка')
# ('Печерський', '1', 'Мечнікова')
# ('Оболонський', '7', 'Героїв Сталінграда')
# ('Печерський', '25', 'Рибальська')
# ("Солом'янський", '8', 'Березова')
# ('Печерський', '7', 'Саперне Поле')
# ('Голосіївський, Печерський', '23', 'Антоновича')
# (None, '3', 'Маккейна')
# ('Печерський', '17', 'Лейпцизька')
# ('Дарницький', '14', 'Драгоманова')
# (None, '23', 'Коновальця')
# (None, '3', 'Василя Стуса')
# (None, '24', 'Тютюнника')
# ('Шевченківський', '15', 'Січових Стрільців')
# ('Дніпровський', '6', 'Райдужна')
# (None, '15', 'Закревського')
# ('Шевченківський', '9', 'Тургенєвська')
# ('Голосіївський', '20', 'Васильківська')
# (None, '20', "Зої Космодем'янської")
# (None, '18', 'Радченка')
# (None, '8', 'Сверстюка')
# ('Деснянський', '24', 'Милославська')
# ('Голосіївський', '23', 'Метрологічна')
# ('Голосіївський', '4', 'Деміївська')
# ('Голосіївський', '4', 'Деміївська')
# ('Святошинський', '1', 'Перемоги')
# ('Шевченківський', '1', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '1', 'Перемоги')
# ('Подільський, Оболонський', '13', 'Вишгородська')
# (None, '23', 'Маккейна')
# (None, '14', None)
# ('Святошинський', '4', 'Перемоги')
# ('Шевченківський', '4', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '4', 'Перемоги')
# ('Оболонський', '4', 'Балтійський')
# ('Печерський', '1', 'Звіринецька')
# ('Дарницький', '13', 'Ревуцького')
# ('Подільський', '9', 'Правди')
# ('Деснянський', '15', 'Милославська')
# (None, '18', 'Вербицького')
# ("Солом'янський", '22', 'Новгородська')
# (None, '17', 'Бажана')
# ('Подільський', '11', 'Канівська')
# ('Святошинський', '3', 'Максимовича')
# (None, '11', 'Донця')
# (None, '4', 'Драгомирова')
# ('Подільський', '4', 'Тираспольська')
# ('Голосіївський, Печерський, Шевченківський', '3', 'Саксаганського')
# ('Подільський', '7', 'Тираспольська')
# ('Дарницький', '1', 'Зарічна')
# (None, '23', 'Гонгадзе')
# (None, '9', 'Українки')
# ('Подільський', '15', 'Світлицького')
# (None, '18', 'Воробйова')
# ('Дніпровський', '16', 'Каховська')
# ('Шевченківський', '7', 'Глибочицька')
# (None, '25', 'Білокур')
# ('Оболонський', '25', 'Балтійський')
# ('Голосіївський, Печерський', '7', 'Антоновича')
# (None, '9', 'Кондратюка')
# (None, '1', 'Гончара')
# ('Дарницький', '2', 'Ревуцького')
# (None, '8', '*** not found')
# ('Дарницький', '4', 'Драгоманова')
# (None, '24', 'Сім’ї Кульженків')
# (None, '13', 'Панельна')
# (None, '4', 'Вільямса')
# ('Голосіївський', '2', 'Голосіївська')
# ('Голосіївський', '2', 'Голосіївська')
# ('Оболонський', '18', 'Оболонський')
# ("Солом'янський", '6', 'Миколи Голего')
# ('Оболонський', '17', 'Дніпровська')
# (None, '11', 'Малиновського')
# ('Шевченківський', '9', 'Назарівська')
# ('Шевченківський', '23', 'Гоголівська')
# ('Шевченківський', '4', 'Дорогожицька')
# ('Оболонський', '15', 'Петропавлівська')
# ('Подільський', '15', 'Петропавлівська')
# (None, '6', 'Грушевського')
# (None, '21', 'Іллєнка')
# (None, '10', 'Липківського')
# ("Солом'янський", '8', 'Ушинського')
# ("Солом'янський", '8', 'Ушинського')
# ('Дарницький', '10', 'Польова')
# ('Деснянський', '10', 'Польова')
# ("Солом'янський", '10', 'Польова')
# ('Печерський', '5', 'Саперне Поле')
# (None, '6', 'Панельна')
# (None, '4', 'Коновальця')
# (None, '3', 'Хмельницького')
# (None, '9', 'Маккейна')
# ('Голосіївський, Печерський', '24', 'Антоновича')
# ('Дарницький', '5', 'Толстого')
# ('Печерський', '9', 'Дружби Народів')
# ('Оболонський', '17', 'Оболонський')
# ('Шевченківський', '17', 'Багговутівська')
# (None, '20', 'Антонова')
# ('Голосіївський, Шевченківський', '4', 'Володимирська')
# (None, '22', 'Українки')
# (None, '3', 'Сім’ї Кульженків')
# (None, '1', 'Коновальця')
# (None, '28', 'Мирного')
# ('Печерський', '0', 'Московська')
# ("Солом'янський", '0', 'Московська')
# ('Святошинський', '5', 'Жмеринська')
# (None, '12', 'Бойчука')
# (None, '5', 'Липківського')
# ('Печерський', '8', 'Лабораторний')
# ('Печерський', '0', 'Інститутська')
# (None, '7', 'Українки')
# ('Печерський, Шевченківський', '3', 'Хрещатик')
# ('Оболонський', '20', 'Дніпровська')
# ('Дарницький', '14', 'Осокорська')
# ('Печерський', '2', 'Саперне Поле')
# (None, '13', 'Комарова')
# (None, '0', 'Драгомирова')
# ('Дарницький', '3', 'Срібнокільська')
# ("Солом'янський", '22', 'Чоколівський')
# ('Печерський', '4', 'Звіринецька')
# ('Подільський, Оболонський', '7', 'Вишгородська')
# (None, '11', 'Драгомирова')
# ('Оболонський', '0', 'Героїв Сталінграда')
# ('Деснянський', '0', 'Будівельників')
# ('Дніпровський', '0', 'Будівельників')
# ('Дніпровський', '0', 'Будівельників')
# ('Святошинський', '0', 'Будівельників')
# (None, '2', 'Іллєнка')
# ('Дарницький', '3', 'Урлівська')
# ('Дарницький', '9', 'Сормовська')
# ('Подільський', '0', 'Правди')
# ('Святошинський', '7', 'Верховинна')
# (None, '17', 'Вербицького')
# (None, '1', '*** not found')
# ('Голосіївський, Шевченківський, Печерський', '15', 'Велика Васильківська')
# (None, '11', 'Бойчука')
# (None, '9', 'Лобановського')
# (None, '0', 'Миколи Шепелєва')
# ('Печерський', '21', 'Кропивницького')
# ('Дарницький', '7', 'Трускавецька')
# ('Голосіївський', '28', 'Голосіївська')
# ('Голосіївський', '28', 'Голосіївська')
# (None, '4', 'Маланюка')
# (None, '4', 'Драгомирова')
# ('Святошинський', '24', 'Юнацька')
# ("Солом'янський", '24', 'Юнацька')
# ('Святошинський', '5', 'Максимовича')
# (None, '3', 'Комарова')
# ('Шевченківський', '1', 'Багговутівська')
# (None, '7', None)
# ('Голосіївський', '10', 'Костанайська')
# ('Дарницький', '10', 'Срібнокільська')
# (None, '1', 'Курчатова')
# ('Печерський', '4', 'Гусовського')
# (None, '5', 'Українки')
# ('Дарницький', '23', 'Драгоманова')
# ('Оболонський', '18', 'Дніпровська')
# (None, '9', 'Заболотного')
# (None, '4', 'Заболотного')
# ('Святошинський', '7', 'Перемоги')
# ('Шевченківський', '7', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '7', 'Перемоги')
# (None, '3', 'Сверстюка')
# (None, '2', 'Липківського')
# (None, '16', 'Маккейна')
# ('Оболонський', '12', 'Дніпровська')
# ('Деснянський', '4', 'Волгоградська')
# ("Солом'янський", '4', 'Волгоградська')
# ("Солом'янський", '5', 'Новопольова')
# ('Дарницький', '3', 'Драгоманова')
# (None, '16', 'Лебедєва')
# (None, '3', '*** not found')
# (None, '10', 'Драгомирова')
# ('Печерський', '22', 'Лейпцизька')
# ('Шевченківський', '10', 'Глибочицька')
# ('Шевченківський', '4', 'Салютна')
# ('Голосіївський', '0', 'Метрологічна')
# ('Подільський', '18', 'Північно-Сирецька')
# ('Подільський', '1', 'Правди')
# (None, '1', 'Вернадського')
# (None, '6', 'Пчілки')
# ('Печерський', '12', 'Лейпцизька')
# ('Печерський, Шевченківський', '0', 'Басейна')
# (None, '8', 'Шаповала')
# ('Оболонський', '2', 'Бережанська')
# (None, '17', 'Бойчука')
# ('Святошинський', '6', 'Перемоги')
# ('Шевченківський', '6', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '6', 'Перемоги')
# (None, '0', 'Івана Федорова')
# ('Голосіївський, Печерський', '18', 'Антоновича')
# (None, '4', 'Вільямса')
# (None, '14', 'Бойчука')
# ('Святошинський', '2', 'Перемоги')
# ('Шевченківський', '2', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '2', 'Перемоги')
# ('Голосіївський, Печерський', '9', 'Ковпака')
# ('Дніпровський', '3', 'Русанівський')
# (None, '0', 'Українки')
# ('Дніпровський', '5', 'Празька')
# (None, '15', 'Гончара')
# (None, '24', 'Маккейна')
# ('Оболонський', '4', 'Балтійський')
# ('Шевченківський', '2', 'Білоруська')
# ('Дарницький', '9', 'Драгоманова')
# (None, '14', 'Липківського')
# ('Печерський', '12', 'Новогоспітальна')
# (None, '3', 'Радченка')
# (None, '9', 'Богомольця')
# (None, '9', 'Донця')
# ('Оболонський', '3', 'Оболонський')
# ('Подільський', '9', 'Щекавицька')
# ('Подільський', '9', 'Щекавицька')
# ('Деснянський', '22', 'Пожарського')
# ('Дніпровський', '22', 'Пожарського')
# ('Подільський', '25', 'Полкова')
# (None, '9', 'Донця')
# (None, '3', 'Палладіна')
# (None, '17', 'Бойчука')
# (None, '0', 'Липківського')
# ('Шевченківський', '21', 'Павлівська')
# (None, '2', 'Івашкевича')
# ("Солом'янський", '15', 'Іскрівська')
# ('Святошинський', '1', 'Максимовича')
# (None, '6', '*** not found')
# (None, '18', 'Драгомирова')
# ('Голосіївський', '22', 'Теремківська')
# ('Дарницький', '19', 'Осокорська')
# ('Подільський', '24', 'Дмитрівська')
# ('Шевченківський', '24', 'Дмитрівська')
# (None, '5', 'Кондратюка')
# ('Дніпровський', '22', 'Регенераторна')
# (None, '3', None)
# ('Шевченківський', '25', 'Глибочицька')
# ('Оболонський', '12', 'Героїв Сталінграда')
# ("Солом'янський, Шевченківський ", '0', 'Борщагівська')
# ('Дарницький', '21', 'Ревуцького')
# ('Святошинський', '19', 'Юнацька')
# ("Солом'янський", '19', 'Юнацька')
# (None, '21', 'Заболотного')
# ('Оболонський', '8', 'Автозаводська')
# (None, '17', 'Заболотного')
# ('Голосіївський, Печерський, Шевченківський', '0', 'Саксаганського')
# ('Дарницький', '6', 'Зарічна')
# (None, '20', '*** not found')
# (None, '8', 'Невська')
# ('Оболонський', '12', 'Героїв Сталінграда')
# ('Дарницький', '0', 'Вишняківська')
# (None, '8', 'Драгомирова')
# (None, '15', 'Драгомирова')
# (None, '1', 'Гавела')
# ('Дарницький', '18', 'Здолбунівська')
# (None, '15', 'Драгомирова')
# ('Печерський', '2', 'Мечнікова')
# (None, '0', '*** not found')
# ('Святошинський', '2', 'Максимовича')
# ('Шевченківський', '3', 'Багговутівська')
# ('Шевченківський', '24', 'Шолуденка')
# ('Подільський', '5', 'Щекавицька')
# ('Подільський', '5', 'Щекавицька')
# (None, '4', 'Коласа')
# (None, '15', '*** not found')
# (None, '6', '*** not found')
# ('Святошинський', '9', 'Перемоги')
# ('Шевченківський', '9', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '9', 'Перемоги')
# (None, '23', '*** not found')
# (None, '29', 'Наумова')
# ('Святошинський', '5', 'Перемоги')
# ('Шевченківський', '5', 'Перемоги')
# ("Шевченківський, Святошинський, Солом'янський", '5', 'Перемоги')
# ('Голосіївський, Шевченківський, Печерський', '19', 'Велика Васильківська')
# (None, '11', 'Червоноткацька')
# ('Подільський, Оболонський', '7', 'Вишгородська')

# %% [markdown]
# #### для аналізу скористатися бібліотекою NumPy

# %%
import numpy as np

# %%
# створити np-масив з списку `result_list`
result_arr = np.delete(result_list, [0,2], 1)

result_arr[result_arr == None] = 0
result_arr = [int(el[0]) for el in result_arr]

# %%
# побудувати словник для результатів аналізу
result_dict = {
    "кількість спостережень"   : len(result_arr)  ,
    "середнє значення"         : round(np.mean(result_arr),1) ,
    "максимальне значення"     : np.max(result_arr) ,
    "мінімальне значення"      : np.min(result_arr) ,
    "стандартне відхилення"    : round(np.std(result_arr),1) ,
    "розмах вариації"          : np.max(result_arr) - np.min(result_arr)
    }
#  [np.nonzero(result_arr)]
print(result_dict)
# Out:
# {'кількість спостережень': 811, 'середнє значення': 9.3, 'максимальне значення': 29, 'мінімальне значення': 0, 'стандартне відхилення': 7.2, 'розмах вариації': 29}

# %%
# вивести шапку
print(
"""
================================================
№  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ     
================================================
"""      
      )

# вивести результати аналізу датасета
i = 1
for key, value in result_dict.items():
    print (f'{i:<3} {key:<25}  {value}')
    i += 1
# Out:
# ================================================
# №  :   РАЙОН        : ПОКАЗЧИК        : ЗНАЧЕННЯ
# ================================================
#
# 1   кількість спостережень     811
# 2   середнє значення           9.3
# 3   максимальне значення       29
# 4   мінімальне значення        0
# 5   стандартне відхилення      7.2
# 6   розмах вариації            29
